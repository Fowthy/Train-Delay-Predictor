# %%
#you first need to download the data from teams and put it in the same folder as this to be able to load the script
#the time is in duration (timedelta) format so that needs to be changed in the future
#here i load the libraries
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import display
import seaborn as sns
import datetime
sns.set_theme()

# %%
January=pd.read_csv('January.csv')
January.drop('Unnamed: 0',axis=1,inplace=True)
January.info()
January
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5458998 entries, 0 to 5458997
# Data columns (total 10 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    object
#  8   Train Departure Actual     object
#  9   Train Delay                object
# dtypes: int64(1), object(9)
# memory usage: 416.5+ MB
#         Station Code            Station Name  Train Number Train Type  \
# 0               HLMS     Haarlem Spaarnwoude         14882   Sprinter
# 1               NSCH        Bad Nieuweschans         37598  Stoptrein
# 2                DVD            Duivendrecht          7495   Sprinter
# 3               DDRS  Dordrecht Stadspolders         36795  Stoptrein
# 4               EMNZ              Emmen Zuid          8083  Stoptrein
# ...              ...                     ...           ...        ...
# 5458993         DDRS  Dordrecht Stadspolders         36782  Stoptrein
# 5458994          HIL                Hillegom          6395   Sprinter
# 5458995           DT                   Delft          5182   Sprinter
# 5458996           VB                Voorburg          9893   Sprinter
# 5458997          HWD           Heerhugowaard          3078  Intercity
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  NS        Amsterdam Centraal      Haarlem Spaarnwoude
# 1              Arriva                 Groningen         Bad Nieuweschans
# 2                  NS          Utrecht Centraal             Duivendrecht
# 3              Arriva                 Gorinchem   Dordrecht Stadspolders
# 4              Arriva                     Emmen               Emmen Zuid
# ...               ...                       ...                      ...
# 5458993        Arriva                 Dordrecht                Dordrecht
# 5458994            NS           Leiden Centraal          Leiden Centraal
# 5458995            NS         Den Haag Centraal        Den Haag Centraal
# 5458996            NS          Utrecht Centraal         Utrecht Centraal
# 5458997            NS                Den Helder               Den Helder
#
#         Train Departure Planned Train Departure Actual Train Delay
# 0          2016-01-01T00:10:00Z   2016-01-01T00:10:00Z        PT0S
# 1          2016-01-01T00:10:00Z   2016-01-01T00:10:00Z        PT0S
# 2          2016-01-01T00:11:00Z   2016-01-01T00:11:00Z        PT0S
# 3          2016-01-01T00:11:00Z   2016-01-01T00:11:00Z        PT0S
# 4          2016-01-01T00:11:00Z   2016-01-01T00:11:00Z        PT0S
# ...                         ...                    ...         ...
# 5458993    2016-01-31T22:58:00Z   2016-01-31T22:58:00Z        PT0S
# 5458994    2016-01-31T23:00:00Z   2016-01-31T23:00:00Z        PT0S
# 5458995    2016-01-31T23:00:00Z   2016-01-31T23:00:00Z        PT0S
# 5458996    2016-01-31T23:01:00Z   2016-01-31T23:01:00Z        PT0S
# 5458997    2016-01-31T22:58:00Z   2016-01-31T23:00:38Z     PT2M38S
#
# [5458998 rows x 10 columns]

# %%
#First I make a date from the date planned departure, then i make it a string in a new column so i can split it into 2 columns 
#and make the date alone a date, i also delete the str column i used for splitting the date and time
January['Train Departure Planned']=pd.to_datetime(January['Train Departure Planned'], format="%Y-%m-%dT%H:%M:%SZ")
January['Train Departure Planned1']=January['Train Departure Planned'].astype(str)
January[['DepartureDatePlanned','DepartureTimePlanned']]= January['Train Departure Planned1'].str.split(' ', expand = True)
January['DepartureDatePlanned']=pd.to_datetime(January['DepartureDatePlanned'])
January
#then i make the planned depature time a time delta (Actually want to make it a normal time format)
January['DepartureTimePlanned'] = January.apply(lambda row: pd.to_datetime(row.DepartureDatePlanned).time(), axis=1)
January.drop('Train Departure Planned1', axis=1, inplace=True)
print(January.info())
January
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5458998 entries, 0 to 5458997
# Data columns (total 12 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     object
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
# dtypes: datetime64[ns](2), int64(1), object(9)
# memory usage: 499.8+ MB
# None
#         Station Code            Station Name  Train Number Train Type  \
# 0               HLMS     Haarlem Spaarnwoude         14882   Sprinter
# 1               NSCH        Bad Nieuweschans         37598  Stoptrein
# 2                DVD            Duivendrecht          7495   Sprinter
# 3               DDRS  Dordrecht Stadspolders         36795  Stoptrein
# 4               EMNZ              Emmen Zuid          8083  Stoptrein
# ...              ...                     ...           ...        ...
# 5458993         DDRS  Dordrecht Stadspolders         36782  Stoptrein
# 5458994          HIL                Hillegom          6395   Sprinter
# 5458995           DT                   Delft          5182   Sprinter
# 5458996           VB                Voorburg          9893   Sprinter
# 5458997          HWD           Heerhugowaard          3078  Intercity
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  NS        Amsterdam Centraal      Haarlem Spaarnwoude
# 1              Arriva                 Groningen         Bad Nieuweschans
# 2                  NS          Utrecht Centraal             Duivendrecht
# 3              Arriva                 Gorinchem   Dordrecht Stadspolders
# 4              Arriva                     Emmen               Emmen Zuid
# ...               ...                       ...                      ...
# 5458993        Arriva                 Dordrecht                Dordrecht
# 5458994            NS           Leiden Centraal          Leiden Centraal
# 5458995            NS         Den Haag Centraal        Den Haag Centraal
# 5458996            NS          Utrecht Centraal         Utrecht Centraal
# 5458997            NS                Den Helder               Den Helder
#
#         Train Departure Planned Train Departure Actual Train Delay  \
# 0           2016-01-01 00:10:00   2016-01-01T00:10:00Z        PT0S
# 1           2016-01-01 00:10:00   2016-01-01T00:10:00Z        PT0S
# 2           2016-01-01 00:11:00   2016-01-01T00:11:00Z        PT0S
# 3           2016-01-01 00:11:00   2016-01-01T00:11:00Z        PT0S
# 4           2016-01-01 00:11:00   2016-01-01T00:11:00Z        PT0S
# ...                         ...                    ...         ...
# 5458993     2016-01-31 22:58:00   2016-01-31T22:58:00Z        PT0S
# 5458994     2016-01-31 23:00:00   2016-01-31T23:00:00Z        PT0S
# 5458995     2016-01-31 23:00:00   2016-01-31T23:00:00Z        PT0S
# 5458996     2016-01-31 23:01:00   2016-01-31T23:01:00Z        PT0S
# 5458997     2016-01-31 22:58:00   2016-01-31T23:00:38Z     PT2M38S
#
#         DepartureDatePlanned DepartureTimePlanned
# 0                 2016-01-01             00:00:00
# 1                 2016-01-01             00:00:00
# 2                 2016-01-01             00:00:00
# 3                 2016-01-01             00:00:00
# 4                 2016-01-01             00:00:00
# ...                      ...                  ...
# 5458993           2016-01-31             00:00:00
# 5458994           2016-01-31             00:00:00
# 5458995           2016-01-31             00:00:00
# 5458996           2016-01-31             00:00:00
# 5458997           2016-01-31             00:00:00
#
# [5458998 rows x 12 columns]

# %%
# here i basically do the same but for the actual depature
January['Train Departure Actual']=pd.to_datetime(January['Train Departure Actual'], format="%Y-%m-%dT%H:%M:%SZ")
January['Train Departure Actual1']=January['Train Departure Actual'].astype(str)
January[['DepartureDateActual','DepartureTimeActual']]= January['Train Departure Actual1'].str.split(' ', expand = True)
January['DepartureDateActual']=pd.to_datetime(January['DepartureDateActual'])
January
January['DepartureTimeActual'] = January.apply(lambda row: pd.to_datetime(row.DepartureDateActual).time(), axis=1)
January.drop('Train Departure Actual1', axis=1, inplace=True)
print(January.info())
January
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5458998 entries, 0 to 5458997
# Data columns (total 14 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     datetime64[ns]
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
#  12  DepartureDateActual        datetime64[ns]
#  13  DepartureTimeActual        object
# dtypes: datetime64[ns](4), int64(1), object(9)
# memory usage: 583.1+ MB
# None
#         Station Code            Station Name  Train Number Train Type  \
# 0               HLMS     Haarlem Spaarnwoude         14882   Sprinter
# 1               NSCH        Bad Nieuweschans         37598  Stoptrein
# 2                DVD            Duivendrecht          7495   Sprinter
# 3               DDRS  Dordrecht Stadspolders         36795  Stoptrein
# 4               EMNZ              Emmen Zuid          8083  Stoptrein
# ...              ...                     ...           ...        ...
# 5458993         DDRS  Dordrecht Stadspolders         36782  Stoptrein
# 5458994          HIL                Hillegom          6395   Sprinter
# 5458995           DT                   Delft          5182   Sprinter
# 5458996           VB                Voorburg          9893   Sprinter
# 5458997          HWD           Heerhugowaard          3078  Intercity
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  NS        Amsterdam Centraal      Haarlem Spaarnwoude
# 1              Arriva                 Groningen         Bad Nieuweschans
# 2                  NS          Utrecht Centraal             Duivendrecht
# 3              Arriva                 Gorinchem   Dordrecht Stadspolders
# 4              Arriva                     Emmen               Emmen Zuid
# ...               ...                       ...                      ...
# 5458993        Arriva                 Dordrecht                Dordrecht
# 5458994            NS           Leiden Centraal          Leiden Centraal
# 5458995            NS         Den Haag Centraal        Den Haag Centraal
# 5458996            NS          Utrecht Centraal         Utrecht Centraal
# 5458997            NS                Den Helder               Den Helder
#
#         Train Departure Planned Train Departure Actual Train Delay  \
# 0           2016-01-01 00:10:00    2016-01-01 00:10:00        PT0S
# 1           2016-01-01 00:10:00    2016-01-01 00:10:00        PT0S
# 2           2016-01-01 00:11:00    2016-01-01 00:11:00        PT0S
# 3           2016-01-01 00:11:00    2016-01-01 00:11:00        PT0S
# 4           2016-01-01 00:11:00    2016-01-01 00:11:00        PT0S
# ...                         ...                    ...         ...
# 5458993     2016-01-31 22:58:00    2016-01-31 22:58:00        PT0S
# 5458994     2016-01-31 23:00:00    2016-01-31 23:00:00        PT0S
# 5458995     2016-01-31 23:00:00    2016-01-31 23:00:00        PT0S
# 5458996     2016-01-31 23:01:00    2016-01-31 23:01:00        PT0S
# 5458997     2016-01-31 22:58:00    2016-01-31 23:00:38     PT2M38S
#
#         DepartureDatePlanned DepartureTimePlanned DepartureDateActual  \
# 0                 2016-01-01             00:00:00          2016-01-01
# 1                 2016-01-01             00:00:00          2016-01-01
# 2                 2016-01-01             00:00:00          2016-01-01
# 3                 2016-01-01             00:00:00          2016-01-01
# 4                 2016-01-01             00:00:00          2016-01-01
# ...                      ...                  ...                 ...
# 5458993           2016-01-31             00:00:00          2016-01-31
# 5458994           2016-01-31             00:00:00          2016-01-31
# 5458995           2016-01-31             00:00:00          2016-01-31
# 5458996           2016-01-31             00:00:00          2016-01-31
# 5458997           2016-01-31             00:00:00          2016-01-31
#
#         DepartureTimeActual
# 0                  00:00:00
# 1                  00:00:00
# 2                  00:00:00
# 3                  00:00:00
# 4                  00:00:00
# ...                     ...
# 5458993            00:00:00
# 5458994            00:00:00
# 5458995            00:00:00
# 5458996            00:00:00
# 5458997            00:00:00
#
# [5458998 rows x 14 columns]

# %%
#Then i also put the delay in time delta format
January['Train Delay']=pd.to_timedelta(January['Train Delay'].str.strip())
January
# Out:
#         Station Code            Station Name  Train Number Train Type  \
# 0               HLMS     Haarlem Spaarnwoude         14882   Sprinter
# 1               NSCH        Bad Nieuweschans         37598  Stoptrein
# 2                DVD            Duivendrecht          7495   Sprinter
# 3               DDRS  Dordrecht Stadspolders         36795  Stoptrein
# 4               EMNZ              Emmen Zuid          8083  Stoptrein
# ...              ...                     ...           ...        ...
# 5458993         DDRS  Dordrecht Stadspolders         36782  Stoptrein
# 5458994          HIL                Hillegom          6395   Sprinter
# 5458995           DT                   Delft          5182   Sprinter
# 5458996           VB                Voorburg          9893   Sprinter
# 5458997          HWD           Heerhugowaard          3078  Intercity
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  NS        Amsterdam Centra
# 1                  NS        Amsterdam Centraal       Amsterdam Centraal
# 2              Arriva                 Groningen                Groningen
# 3                  NS                Den Helder               Den Helder
# 4                  NS                Vlissingen               Vlissingen
# ...               ...                       ...                      ...
# 5099986        Arriva                    Arnhem                   Arnhem
# 5099987            NS        Amsterdam Centraal       Amsterdam Centraal
# 5099988            NS          Utrecht Centraal         Utrecht Centraal
# 5099989            NS          Schiphol Airport         Schiphol Airport
# 5099990            NS          Utrecht Centraal         Utrecht Centraal
#
#         Train Departure Planned Train Departure Actual Train Delay
# 0          2016-02-01T00:10:00Z   2016-02-01T00:10:00Z        PT0S
# 1          2016-02-01T00:10:00Z   2016-02-01T00:10:00Z        PT0S
# 2          2016-02-01T00:10:00Z   2016-02-01T00:10:00Z        PT0S
# 3          2016-02-01T00:10:00Z   2016-02-01T00:10:00Z        PT0S
# 4          2016-01-31T23:01:00Z   2016-01-31T23:01:00Z        PT0S
# ...                         ...                    ...         ...
# 5099986    2016-02-29T07:58:00Z   2016-02-29T08:00:45Z     PT2M45S
# 5099987    2016-02-29T07:47:00Z   2016-02-29T07:47:00Z        PT0S
# 5099988    2016-02-29T08:02:00Z   2016-02-29T08:02:00Z        PT0S
# 5099989    2016-02-29T08:43:00Z   2016-02-29T08:43:00Z        PT0S
# 5099990    2016-02-29T08:32:00Z   2016-02-29T08:32:00Z        PT0S
#
# [5099991 rows x 10 columns]

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date, i also delete the str column i used for splitting the date and time
February['Train Departure Planned']=pd.to_datetime(February['Train Departure Planned'], format="%Y-%m-%dT%H:%M:%SZ")
February['Train Departure Planned1']=February['Train Departure Planned'].astype(str)
February[['DepartureDatePlanned','DepartureTimePlanned']]= February['Train Departure Planned1'].str.split(' ', expand = True)
February['DepartureDatePlanned']=pd.to_datetime(February['DepartureDatePlanned'])
February.drop('Train Departure Planned1', axis=1, inplace=True)
February
#then i make the depature time a time delta (Actually want to make it a normal time format)
February['DepartureTimePlanned'] = February.apply(lambda row: pd.to_datetime(row.DepartureDatePlanned).time(), axis=1)
print(February.info())
February
# then i basically do the same but for the actual departure
February['Train Departure Actual']=pd.to_datetime(February['Train Departure Actual'], format="%Y-%m-%dT%H:%M:%SZ")
February['Train Departure Actual1']=February['Train Departure Actual'].astype(str)
February[['DepartureDateActual','DepartureTimeActual']]= February['Train Departure Actual1'].str.split(' ', expand = True)
February['DepartureDateActual']=pd.to_datetime(February['DepartureDateActual'])
February.drop('Train Departure Actual1', axis=1, inplace=True)
February
February['DepartureTimeActual'] = February.apply(lambda row: pd.to_datetime(row.DepartureDateActual).time(), axis=1)
print(February.info())
February
#Then i also put the delay in time delta format
February['Train Delay']=pd.to_timedelta(February['Train Delay'].str.strip())
February
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5099991 entries, 0 to 5099990
# Data columns (total 12 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     object
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
# dtypes: datetime64[ns](2), int64(1), object(9)
# memory usage: 466.9+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5099991 entries, 0 to 5099990
# Data columns (total 14 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     datetime64[ns]
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
#  12  DepartureDateActual        datetime64[ns]
#  13  DepartureTimeActual        object
# dtypes: datetime64[ns](4), int64(1), object(9)
# memory usage: 544.7+ MB
# None
#         Station Code         Station Name  Train Number Train Type  \
# 0                VDW     Vlaardingen West          4197   Sprinter
# 1               HLMS  Haarlem Spaarnwoude         14882   Sprinter
# 2               NSCH     Bad Nieuweschans         37598  Stoptrein
# 3                HWD        Heerhugowaard          4082   Sprinter
# 4                BGN       Bergen op Zoom          2674  Intercity
# ...              ...                  ...           ...        ...
# 5099986           WL                 Wehl         30928  Stoptrein
# 5099987          HLM              Haarlem          2118  Intercity
# 5099988           HT     's-Hertogenbosch         16026   Sprinter
# 5099989           UT     Utrecht Centraal        303528  Intercity
# 5099990           HT     's-Hertogenbosch         16028   Sprinter
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  NS        Rotterdam Centraal       Rotterdam Centraal
# 1                  NS        Amsterdam Centraal       Amsterdam Centraal
# 2              Arriva                 Groningen                Groningen
# 3                  NS                Den Helder               Den Helder
# 4                  NS                Vlissingen               Vlissingen
# ...               ...                       ...                      ...
# 5099986        Arriva                    Arnhem                   Arnhem
# 5099987            NS        Amsterdam Centraal       Amsterdam Centraal
# 5099988            NS          Utrecht Centraal         Utrecht Centraal
# 5099989            NS          Schiphol Airport         Schiphol Airport
# 5099990            NS          Utrecht Centraal         Utrecht Centraal
#
#         Train Departure Planned Train Departure Actual     Train Delay  \
# 0           2016-02-01 00:10:00    2016-02-01 00:10:00 0 days 00:00:00
# 1           2016-02-01 00:10:00    2016-02-01 00:10:00 0 days 00:00:00
# 2           2016-02-01 00:10:00    2016-02-01 00:10:00 0 days 00:00:00
# 3           2016-02-01 00:10:00    2016-02-01 00:10:00 0 days 00:00:00
# 4           2016-01-31 23:01:00    2016-01-31 23:01:00 0 days 00:00:00
# ...                         ...                    ...             ...
# 5099986     2016-02-29 07:58:00    2016-02-29 08:00:45 0 days 00:02:45
# 5099987     2016-02-29 07:47:00    2016-02-29 07:47:00 0 days 00:00:00
# 5099988     2016-02-29 08:02:00    2016-02-29 08:02:00 0 days 00:00:00
# 5099989     2016-02-29 08:43:00    2016-02-29 08:43:00 0 days 00:00:00
# 5099990     2016-02-29 08:32:00    2016-02-29 08:32:00 0 days 00:00:00
#
#         DepartureDatePlanned DepartureTimePlanned DepartureDateActual  \
# 0                 2016-02-01             00:00:00          2016-02-01
# 1                 2016-02-01             00:00:00          2016-02-01
# 2                 2016-02-01             00:00:00          2016-02-01
# 3                 2016-02-01             00:00:00          2016-02-01
# 4                 2016-01-31             00:00:00          2016-01-31
# ...                      ...                  ...                 ...
# 5099986           2016-02-29             00:00:00          2016-02-29
# 5099987           2016-02-29             00:00:00          2016-02-29
# 5099988           2016-02-29             00:00:00          2016-02-29
# 5099989           2016-02-29             00:00:00          2016-02-29
# 5099990           2016-02-29             00:00:00          2016-02-29
#
#         DepartureTimeActual
# 0                  00:00:00
# 1                  00:00:00
# 2                  00:00:00
# 3                  00:00:00
# 4                  00:00:00
# ...                     ...
# 5099986            00:00:00
# 5099987            00:00:00
# 5099988            00:00:00
# 5099989            00:00:00
# 5099990            00:00:00
#
# [5099991 rows x 14 columns]

# %%
March=pd.read_csv('March.csv')
March.drop('Unnamed: 0',axis=1,inplace=True)
March.info()
March
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5433078 entries, 0 to 5433077
# Data columns (total 10 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    object
#  8   Train Departure Actual     object
#  9   Train Delay                object
# dtypes: int64(1), object(9)
# memory usage: 414.5+ MB
#         Station Code            Station Name  Train Number Train Type  \
# 0               LEDN         Leiden Centraal          2691  Intercity
# 1               HLMS     Haarlem Spaarnwoude         14882   Sprinter
# 2               NSCH        Bad Nieuweschans         37598  Stoptrein
# 3                 CL               Culemborg         16084   Sprinter
# 4                CAS               Castricum         14889   Sprinter
# ...              ...                     ...           ...        ...
# 5433073         ASSP  Amsterdam Science Park          5889   Sprinter
# 5433074           WP                   Weesp          4684   Sprinter
# 5433075           ZP                 Zutphen          3691  Intercity
# 5433076          GDG        Gouda Goverwelle          9882   Sprinter
# 5433077           DB        Driebergen-Zeist          3087  Intercity
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  NS        Amsterdam Centraal       Amsterdam Centraal
# 1                  NS        Amsterdam Centraal       Amsterdam Centraal
# 2              Arriva                 Groningen                Groningen
# 3                  NS          Utrecht Centraal         Utrecht Centraal
# 4                  NS                     Hoorn                    Hoorn
# ...               ...                       ...                      ...
# 5433073            NS                Amersfoort               Amersfoort
# 5433074            NS        Amsterdam Centraal       Amsterdam Centraal
# 5433075            NS                    Arnhem                   Arnhem
# 5433076            NS         Den Haag Centraal        Den Haag Centraal
# 5433077            NS                  Nijmegen                 Nijmegen
#
#         Train Departure Planned Train Departure Actual Train Delay
# 0          2016-02-29T22:57:00Z   2016-02-29T23:03:34Z     PT6M34S
# 1          2016-03-01T00:10:00Z   2016-03-01T00:10:00Z        PT0S
# 2          2016-03-01T00:10:00Z   2016-03-01T00:10:00Z        PT0S
# 3          2016-02-29T22:59:00Z   2016-02-29T22:59:00Z        PT0S
# 4          2016-02-29T22:59:00Z   2016-02-29T22:59:00Z        PT0S
# ...                         ...                    ...         ...
# 5433073    2016-03-31T22:00:00Z   2016-03-31T22:00:36Z       PT36S
# 5433074    2016-03-31T22:03:00Z   2016-03-31T22:03:00Z        PT0S
# 5433075    2016-03-31T21:58:00Z   2016-03-31T21:59:30Z     PT1M30S
# 5433076    2016-03-31T22:04:00Z   2016-03-31T22:04:00Z        PT0S
# 5433077    2016-03-31T22:01:00Z   2016-03-31T22:01:00Z        PT0S
#
# [5433078 rows x 10 columns]

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date, i also delete the str column i used for splitting the date and time
March['Train Departure Planned']=pd.to_datetime(March['Train Departure Planned'], format="%Y-%m-%dT%H:%M:%SZ")
March['Train Departure Planned1']=March['Train Departure Planned'].astype(str)
March[['DepartureDatePlanned','DepartureTimePlanned']]= March['Train Departure Planned1'].str.split(' ', expand = True)
March['DepartureDatePlanned']=pd.to_datetime(March['DepartureDatePlanned'])
March.drop('Train Departure Planned1', axis=1, inplace=True)
March
#then i make the depature time a time delta (Actually want to make it a normal time format)
March['DepartureTimePlanned'] = March.apply(lambda row: pd.to_datetime(row.DepartureDatePlanned).time(), axis=1)
print(March.info())
March
#then i basically do the same but for the actual departure
March['Train Departure Actual']=pd.to_datetime(March['Train Departure Actual'], format="%Y-%m-%dT%H:%M:%SZ")
March['Train Departure Actual1']=March['Train Departure Actual'].astype(str)
March[['DepartureDateActual','DepartureTimeActual']]= March['Train Departure Actual1'].str.split(' ', expand = True)
March['DepartureDateActual']=pd.to_datetime(March['DepartureDateActual'])
March.drop('Train Departure Actual1', axis=1, inplace=True)
March
March['DepartureTimeActual'] = March.apply(lambda row: pd.to_datetime(row.DepartureDateActual).time(), axis=1)
print(March.info())
March
#Then i also put the delay in time delta format
March['Train Delay']=pd.to_timedelta(March['Train Delay'].str.strip())
March
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5433078 entries, 0 to 5433077
# Data columns (total 12 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     object
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
# dtypes: datetime64[ns](2), int64(1), object(9)
# memory usage: 497.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5433078 entries, 0 to 5433077
# Data columns (total 14 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     datetime64[ns]
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
#  12  DepartureDateActual        datetime64[ns]
#  13  DepartureTimeActual        object
# dtypes: datetime64[ns](4), int64(1), object(9)
# memory usage: 580.3+ MB
# None
#         Station Code            Station Name  Train Number Train Type  \
# 0               LEDN         Leiden Centraal          2691  Intercity
# 1               HLMS     Haarlem Spaarnwoude         14882   Sprinter
# 2               NSCH        Bad Nieuweschans         37598  Stoptrein
# 3                 CL               Culemborg         16084   Sprinter
# 4                CAS               Castricum         14889   Sprinter
# ...              ...                     ...           ...        ...
# 5433073         ASSP  Amsterdam Science Park          5889   Sprinter
# 5433074           WP                   Weesp          4684   Sprinter
# 5433075           ZP                 Zutphen          3691  Intercity
# 5433076          GDG        Gouda Goverwelle          9882   Sprinter
# 5433077           DB        Driebergen-Zeist          3087  Intercity
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  NS        Amsterdam Centraal       Amsterdam Centraal
# 1                  NS        Amsterdam Centraal       Amsterdam Centraal
# 2              Arriva                 Groningen                Groningen
# 3                  NS          Utrecht Centraal         Utrecht Centraal
# 4                  NS                     Hoorn                    Hoorn
# ...               ...                       ...                      ...
# 5433073            NS                Amersfoort               Amersfoort
# 5433074            NS        Amsterdam Centraal       Amsterdam Centraal
# 5433075            NS                    Arnhem                   Arnhem
# 5433076            NS         Den Haag Centraal        Den Haag Centraal
# 5433077            NS                  Nijmegen                 Nijmegen
#
#         Train Departure Planned Train Departure Actual     Train Delay  \
# 0           2016
#
#         Train Departure Planned Train Departure Actual Train Delay
# 0          2016-03-31T21:59:00Z   2016-03-31T22:08:42Z     PT9M42S
# 1          2016-03-31T22:06:00Z   2016-03-31T22:15:10Z     PT9M10S
# 2          2016-03-31T22:11:00Z   2016-03-31T22:19:46Z     PT8M46S
# 3          2016-03-31T22:15:00Z   2016-03-31T22:23:32Z     PT8M32S
# 4          2016-03-31T22:24:00Z   2016-03-31T22:31:52Z     PT7M52S
# ...                         ...                    ...         ...
# 2096525    2016-04-12T13:12:00Z   2016-04-12T13:13:19Z     PT1M19S
# 2096526    2016-04-12T13:15:00Z   2016-04-12T13:15:00Z        PT0S
# 2096527    2016-04-12T13:12:00Z   2016-04-12T13:12:00Z        PT0S
# 2096528    2016-04-12T13:16:00Z   2016-04-12T13:16:00Z        PT0S
# 2096529                     NaN                    NaN         NaN
#
# [2096530 rows x 10 columns]

# %%
#First I delete the row with na's then i make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date, i also delete the str column i used for splitting the date and time
April.dropna(subset=['Station Name', 'Train Number'], inplace=True)
April['Train Departure Planned']=pd.to_datetime(April['Train Departure Planned'], format="%Y-%m-%dT%H:%M:%SZ")
April['Train Departure Planned1']=April['Train Departure Planned'].astype(str)
April[['DepartureDatePlanned','DepartureTimePlanned']]= April['Train Departure Planned1'].str.split(' ', expand = True)
April['DepartureDatePlanned']=pd.to_datetime(April['DepartureDatePlanned'])
April.drop('Train Departure Planned1', axis=1, inplace=True)
April
#then i make the depature time a time delta (Actually want to make it a normal time format)
April['DepartureTimePlanned'] = April.apply(lambda row: pd.to_datetime(row.DepartureDatePlanned).time(), axis=1)
print(April.info())
April
#then i basically do the same but for the actual departure
April['Train Departure Actual']=pd.to_datetime(April['Train Departure Actual'], format="%Y-%m-%dT%H:%M:%SZ")
April['Train Departure Actual1']=April['Train Departure Actual'].astype(str)
April[['DepartureDateActual','DepartureTimeActual']]= April['Train Departure Actual1'].str.split(' ', expand = True)
April['DepartureDateActual'] = pd.to_datetime(April['DepartureDateActual'])
April.drop('Train Departure Actual1', axis=1, inplace=True)
April
#then i make the depature time a time delta (Actually want to make it a normal time format)
April['DepartureTimeActual'] = April.apply(lambda row: pd.to_datetime(row.DepartureDateActual).time(), axis=1)
print(April.info())
April
#Then i also put the delay in time delta format
April['Train Delay']=pd.to_timedelta(April['Train Delay'].str.strip())
April
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2096529 entries, 0 to 2096528
# Data columns (total 12 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               float64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     object
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
# dtypes: datetime64[ns](2), float64(1), object(9)
# memory usage: 207.9+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2096529 entries, 0 to 2096528
# Data columns (total 14 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               float64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     datetime64[ns]
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
#  12  DepartureDateActual        datetime64[ns]
#  13  DepartureTimeActual        object
# dtypes: datetime64[ns](4), float64(1), object(9)
# memory usage: 239.9+ MB
# None
#         Station Code          Station Name  Train Number Train Type  \
# 0                UTO     Utrecht Overvecht        5786.0   Sprinter
# 1                HOR    Hollandsche Rading        5786.0   Sprinter
# 2               HVSP   Hilversum Sportpark        5786.0   Sprinter
# 3                HVS             Hilversum        5786.0   Sprinter
# 4                NDB        Naarden-Bussum        5786.0   Sprinter
# ...              ...                   ...           ...        ...
# 2096524         GERP  Groningen Europapark       37858.0  Stoptrein
# 2096525          DTZ            Delft Zuid        5048.0   Sprinter
# 2096526          VDG   Vlaardingen Centrum        4146.0   Sprinter
# 2096527          ASD    Amsterdam Centraal        3046.0  Intercity
# 2096528           WL                  Wehl       30754.0  Stoptrein
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  NS                     Weesp                    Weesp
# 1                  NS                     Weesp                    Weesp
# 2                  NS                     Weesp                    Weesp
# 3                  NS                 Hoofddorp                Hoofddorp
# 4                  NS                 Hoofddorp                Hoofddorp
# ...               ...                       ...                      ...
# 2096524        Arriva                 Groningen                Groningen
# 2096525            NS         Den Haag Centraal        Den Haag Centraal
# 2096526            NS   Hoek van Holland Strand  Hoek van Holland Strand
# 2096527            NS                Den Helder               Den Helder
# 2096528         Breng                    Arnhem                   Arnhem
#
#         Train Departure Planned Train Departure Actual     Train Delay  \
# 0           2016-03-31 21:59:00    2016-03-31 22:08:42 0 days 00:09:42
# 1           2016-03-31 22:06:00    2016-03-31 22:15:10 0 days 00:09:10
# 2           2016-03-31 22:11:00    2016-03-31 22:19:46 0 days 00:08:46
# 3           2016-03-31 22:15:00    2016-03-31 22:23:32 0 days 00:08:32
# 4           2016-03-31 22:24:00    2016-03-31 22:31:52 0 days 00:07:52
# ...                         ...                    ...             ...
# 2096524     2016-04-12 13:16:00    2016-04-12 13:16:00 0 days 00:00:00
# 2096525     2016-04-12 13:12:00    2016-04-12 13:13:19 0 days 00:01:19
# 2096526     2016-04-12 13:15:00    2016-04-12 13:15:00 0 days 00:00:00
# 2096527     2016-04-12 13:12:00    2016-04-12 13:12:00 0 days 00:00:00
# 2096528     2016-04-12 13:16:00    2016-04-12 13:16:00 0 days 00:00:00
#
#         DepartureDatePlanned DepartureTimePlanned DepartureDateActual  \
# 0                 2016-03-31             00:00:00          2016-03-31
# 1                 2016-03-31             00:00:00          2016-03-31
# 2                 2016-03-31             00:00:00          2016-03-31
# 3                 2016-03-31             00:00:00          2016-03-31
# 4                 2016-03-31             00:00:00          2016-03-31
# ...                      ...                  ...                 ...
# 2096524           2016-04-12             00:00:00          2016-04-12
# 2096525           2016-04-12             00:00:00          2016-04-12
# 2096526           2016-04-12             00:00:00          2016-04-12
# 2096527           2016-04-12             00:00:00          2016-04-12
# 2096528           2016-04-12             00:00:00          2016-04-12
#
#         DepartureTimeActual
# 0                  00:00:00
# 1                  00:00:00
# 2                  00:00:00
# 3                  00:00:00
# 4                  00:00:00
# ...                     ...
# 2096524            00:00:00
# 2096525            00:00:00
# 2096526            00:00:00
# 2096527            00:00:00
# 2096528            00:00:00
#
# [2096529 rows x 14 columns]

# %%
print(April.isna().sum())
April[April['DepartureTimePlanned'].isna()]
# Out:
# Station Code                 3347
# Station Name                    0
# Train Number                    0
# Train Type                      0
# Train Company                   0
# Train Destination Planned       0
# Train Destination Actual        0
# Train Departure Planned         0
# Train Departure Actual          0
# Train Delay                     0
# DepartureDatePlanned            0
# DepartureTimePlanned            0
# DepartureDateActual             0
# DepartureTimeActual             0
# dtype: int64
# Empty DataFrame
# Columns: [Station Code, Station Name, Train Number, Train Type, Train Company, Train Destination Planned, Train Destination Actual, Train Departure Planned, Train Departure Actual, Train Delay, DepartureDatePlanned, DepartureTimePlanned, DepartureDateActual, DepartureTimeActual]
# Index: []

# %%
May=pd.read_csv('May.csv')
May.drop('Unnamed: 0',axis=1,inplace=True)
May.info()
May
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5718506 entries, 0 to 5718505
# Data columns (total 10 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    object
#  8   Train Departure Actual     object
#  9   Train Delay                object
# dtypes: int64(1), object(9)
# memory usage: 436.3+ MB
#         Station Code          Station Name  Train Number Train Type  \
# 0                 WZ                 Wezep          5688   Sprinter
# 1                UTO     Utrecht Overvecht          5786   Sprinter
# 2                 WH                 Wijhe          3680  Intercity
# 3                UTO     Utrecht Overvecht          5786   Sprinter
# 4               GERP  Groningen Europapark          9196   Sprinter
# ...              ...                   ...           ...        ...
# 5718501          HAD  Heemstede-Aerdenhout          2180  Intercity
# 5718502           OT            Oisterwijk          5288   Sprinter
# 5718503         HWZB    Halfweg-Zwanenburg          5478   Sprinter
# 5718504          ASS  Amsterdam Sloterdijk          5478   Sprinter
# 5718505          BRD           Barendrecht         15184   Sprinter
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  NS          Utrecht Centraal         Utrecht Centraal
# 1                  NS                     Weesp                    Weesp
# 2                  NS                    Zwolle                   Zwolle
# 3                  NS                     Weesp                    Weesp
# 4                  NS                     Assen                    Assen
# ...               ...                       ...                      ...
# 5718501            NS        Amsterdam Centraal       Amsterdam Centraal
# 5718502            NS      Tilburg Universiteit     Tilburg Universiteit
# 5718503            NS        Amsterdam Centraal       Amsterdam Centraal
# 5718504            NS        Amsterdam Centraal       Amsterdam Centraal
# 5718505            NS         Den Haag Centraal        Den Haag Centraal
#
#         Train Departure Planned Train Departure Actual Train Delay
# 0          2016-04-30T21:58:00Z   2016-04-30T21:58:00Z        PT0S
# 1          2016-04-30T21:59:00Z   2016-04-30T22:00:00Z        PT1M
# 2          2016-04-30T22:00:00Z   2016-04-30T22:00:00Z        PT0S
# 3          2016-04-30T21:59:00Z   2016-04-30T22:00:00Z        PT1M
# 4          2016-04-30T23:10:00Z   2016-04-30T23:10:00Z        PT0S
# ...                         ...                    ...         ...
# 5718501    2016-05-31T22:11:00Z   2016-05-31T22:12:08Z      PT1M8S
# 5718502    2016-05-31T21:57:00Z   2016-05-31T21:59:28Z     PT2M28S
# 5718503    2016-05-31T21:59:00Z   2016-05-31T22:00:54Z     PT1M54S
# 5718504    2016-05-31T22:04:00Z   2016-05-31T22:05:30Z     PT1M30S
# 5718505    2016-05-31T22:01:00Z   2016-05-31T22:01:00Z        PT0S
#
# [5718506 rows x 10 columns]

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date, i also delete the str column i used for splitting the date and time
May['Train Departure Planned']=pd.to_datetime(May['Train Departure Planned'], format="%Y-%m-%dT%H:%M:%SZ")
May['Train Departure Planned1']=May['Train Departure Planned'].astype(str)
May[['DepartureDatePlanned','DepartureTimePlanned']]= May['Train Departure Planned1'].str.split(' ', expand = True)
May['DepartureDatePlanned']=pd.to_datetime(May['DepartureDatePlanned'])
May.drop('Train Departure Planned1', axis=1, inplace=True)
May
#then i make the depature time a time delta (Actually want to make it a normal time format)
May['DepartureTimePlanned'] = May.apply(lambda row: pd.to_datetime(row.DepartureDatePlanned).time(), axis=1)
print(May.info())
May
#then i basically do the same but for the actual departure

May['Train Departure Actual']=pd.to_datetime(May['Train Departure Actual'], format="%Y-%m-%dT%H:%M:%SZ")
May['Train Departure Actual1']=May['Train Departure Actual'].astype(str)
May[['DepartureDateActual','DepartureTimeActual']]= May['Train Departure Actual1'].str.split(' ', expand = True)
May['DepartureDateActual']=pd.to_datetime(May['DepartureDateActual'])
May.drop('Train Departure Actual1', axis=1, inplace=True)
May
May['DepartureTimeActual'] = May.apply(lambda row: pd.to_datetime(row.DepartureDateActual).time(), axis=1)
print(May.info())
May
#Then i also put the delay in time delta format
May['Train Delay']=pd.to_timedelta(May['Train Delay'].str.strip())
May
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5718506 entries, 0 to 5718505
# Data columns (total 12 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     object
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
# dtypes: datetime64[ns](2), int64(1), object(9)
# memory usage: 523.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5718506 entries, 0 to 5718505
# Data columns (total 14 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     datetime64[ns]
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
#  12  DepartureDateActual        datetime64[ns]
#  13  DepartureTimeActual        object
# dtypes: datetime64[ns](4), int64(1), object(9)
# memory usage: 610.8+ MB
# None
#         Station Code          Station Name  Train Number Train Type  \
# 0                 WZ                 Wezep          5688   Sprinter
# 1                UTO     Utrecht Overvecht          5786   Sprinter
# 2                 WH                 Wijhe          3680  Intercity
# 3                UTO     Utrecht Overvecht          5786   Sprinter
# 4               GERP  Groningen Europapark          9196   Sprinter
# ...              ...                   ...           ...        ...
# 5718501          HAD  Heemstede-Aerdenhout          2180  Intercity
# 5718502           OT            Oisterwijk          5288   Sprinter
# 5718503         HWZB    Halfweg-Zwanenburg          5478   Sprinter
# 5718504          ASS  Amsterdam Sloterdijk          5478   Sprinter
# 5718505          BRD           Barendrecht         15184   Sprinter
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  N
# 1                  NS        Amsterdam Centraal       Amsterdam Centraal
# 2                  NS        Rotterdam Centraal       Rotterdam Centraal
# 3              Arriva                 Groningen                Groningen
# 4                  NS                     Venlo                    Venlo
# ...               ...                       ...                      ...
# 5743206            NS                     Hoorn                    Hoorn
# 5743207            NS                    Deurne                   Deurne
# 5743208            NS          's-Hertogenbosch         's-Hertogenbosch
# 5743209    Valleilijn                Amersfoort               Amersfoort
# 5743210            NS                Amersfoort               Amersfoort
#
#         Train Departure Planned Train Departure Actual Train Delay
# 0          2016-05-31T21:59:00Z   2016-05-31T22:00:00Z        PT1M
# 1          2016-05-31T23:10:00Z   2016-05-31T23:10:00Z        PT0S
# 2          2016-05-31T23:10:00Z   2016-05-31T23:10:00Z        PT0S
# 3          2016-05-31T23:10:00Z   2016-05-31T23:10:00Z        PT0S
# 4          2016-05-31T21:51:00Z   2016-05-31T22:10:17Z    PT19M17S
# ...                         ...                    ...         ...
# 5743206    2016-06-30T22:09:00Z   2016-06-30T22:09:00Z        PT0S
# 5743207    2016-06-30T21:58:00Z   2016-06-30T22:00:55Z     PT2M55S
# 5743208    2016-06-30T21:59:00Z   2016-06-30T21:59:00Z        PT0S
# 5743209    2016-06-30T21:59:00Z   2016-06-30T21:59:00Z        PT0S
# 5743210    2016-06-30T21:54:00Z   2016-06-30T22:00:09Z      PT6M9S
#
# [5743211 rows x 10 columns]

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date, i also delete the str column i used for splitting the date and time
June['Train Departure Planned']=pd.to_datetime(June['Train Departure Planned'], format="%Y-%m-%dT%H:%M:%SZ")
June['Train Departure Planned1']=June['Train Departure Planned'].astype(str)
June[['DepartureDatePlanned','DepartureTimePlanned']]= June['Train Departure Planned1'].str.split(' ', expand = True)
June['DepartureDatePlanned']=pd.to_datetime(June['DepartureDatePlanned'])
June.drop('Train Departure Planned1', axis=1, inplace=True)
June
#then i make the depature time a time delta (Actually want to make it a normal time format)
June['DepartureTimePlanned'] = June.apply(lambda row: pd.to_datetime(row.DepartureDatePlanned).time(), axis=1)
print(June.info())
June
#then i basically do the same but for the actual departure
June['Train Departure Actual']=pd.to_datetime(June['Train Departure Actual'], format="%Y-%m-%dT%H:%M:%SZ")
June['Train Departure Actual1']=June['Train Departure Actual'].astype(str)
June[['DepartureDateActual','DepartureTimeActual']]= June['Train Departure Actual1'].str.split(' ', expand = True)
June['DepartureDateActual']=pd.to_datetime(June['DepartureDateActual'])
June.drop('Train Departure Actual1', axis=1, inplace=True)
June
#then i make the depature time a time delta (Actually want to make it a normal time format)
June['DepartureTimeActual'] = June.apply(lambda row: pd.to_datetime(row.DepartureDateActual).time(), axis=1)
print(June.info())
June
#Then i also put the delay in time delta format
June['Train Delay']=pd.to_timedelta(June['Train Delay'].str.strip())
June
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5743211 entries, 0 to 5743210
# Data columns (total 12 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     object
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
# dtypes: datetime64[ns](2), int64(1), object(9)
# memory usage: 525.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5743211 entries, 0 to 5743210
# Data columns (total 14 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     datetime64[ns]
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
#  12  DepartureDateActual        datetime64[ns]
#  13  DepartureTimeActual        object
# dtypes: datetime64[ns](4), int64(1), object(9)
# memory usage: 613.4+ MB
# None
#         Station Code         Station Name  Train Number Train Type  \
# 0                UTO    Utrecht Overvecht          5786   Sprinter
# 1               HLMS  Haarlem Spaarnwoude         14882   Sprinter
# 2                VDW     Vlaardingen West          4197   Sprinter
# 3               NSCH     Bad Nieuweschans         37598  Stoptrein
# 4                 BD                Breda          1987  Intercity
# ...              ...                  ...           ...        ...
# 5743206          ASD   Amsterdam Centraal          1584  Intercity
# 5743207          BET                 Best          9687   Sprinter
# 5743208           HM              Helmond          9688   Sprinter
# 5743209          EDC          Ede Centrum         31374  Stoptrein
# 5743210         BSMZ          Bussum Zuid          5887   Sprinter
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  NS                     Weesp                Hilversum
# 1                  NS        Amsterdam Centraal       Amsterdam Centraal
# 2                  NS        Rotterdam Centraal       Rotterdam Centraal
# 3              Arriva                 Groningen                Groningen
# 4                  NS                     Venlo                    Venlo
# ...               ...                       ...                      ...
# 5743206            NS                     Hoorn                    Hoorn
# 5743207            NS                    Deurne                   Deurne
# 5743208            NS          's-Hertogenbosch         's-Hertogenbosch
# 5743209    Valleilijn                Amersfoort               Amersfoort
# 5743210            NS                Amersfoort               Amersfoort
#
#         Train Departure Planned Train Departure Actual     Train Delay  \
# 0           2016-05-31 21:59:00    2016-05-31 22:00:00 0 days 00:01:00
# 1           2016-05-31 23:10:00    2016-05-31 23:10:00 0 days 00:00:00
# 2           2016-05-31 23:10:00    2016-05-31 23:10:00 0 days 00:00:00
# 3           2016-05-31 23:10:00    2016-05-31 23:10:00 0 days 00:00:00
# 4           2016-05-31 21:51:00    2016-05-31 22:10:17 0 days 00:19:17
# ...                         ...                    ...             ...
# 5743206     2016-06-30 22:09:00    2016-06-30 22:09:00 0 days 00:00:00
# 5743207     2016-06-30 21:58:00    2016-06-30 22:00:55 0 days 00:02:55
# 5743208     2016-06-30 21:59:00    2016-06-30 21:59:00 0 days 00:00:00
# 5743209     2016-06-30 21:59:00    2016-06-30 21:59:00 0 days 00:00:00
# 5743210     2016-06-30 21:54:00    2016-06-30 22:00:09 0 days 00:06:09
#
#         DepartureDatePlanned DepartureTimePlanned DepartureDateActual  \
# 0                 2016-05-31             00:00:00          2016-05-31
# 1                 2016-05-31             00:00:00          2016-05-31
# 2                 2016-05-31             00:00:00          2016-05-31
# 3                 2016-05-31             00:00:00          2016-05-31
# 4                 2016-05-31             00:00:00          2016-05-31
# ...                      ...                  ...                 ...
# 5743206           2016-06-30             00:00:00          2016-06-30
# 5743207           2016-06-30             00:00:00          2016-06-30
# 5743208           2016-06-30             00:00:00          2016-06-30
# 5743209           2016-06-30             00:00:00          2016-06-30
# 5743210           2016-06-30             00:00:00          2016-06-30
#
#         DepartureTimeActual
# 0                  00:00:00
# 1                  00:00:00
# 2                  00:00:00
# 3                  00:00:00
# 4                  00:00:00
# ...                     ...
# 5743206            00:00:00
# 5743207            00:00:00
# 5743208            00:00:00
# 5743209            00:00:00
# 5743210            00:00:00
#
# [5743211 rows x 14 columns]

# %%
July=pd.read_csv('July.csv')
July.drop('Unnamed: 0',axis=1,inplace=True)
July.info()
July
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5683049 entries, 0 to 5683048
# Data columns (total 10 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    object
#  8   Train Departure Actual     object
#  9   Train Delay                object
# dtypes: int64(1), object(9)
# memory usage: 433.6+ MB
#         Station Code            Station Name  Train Number Train Type  \
# 0               ASSP  Amsterdam Science Park          5882   Sprinter
# 1                SDM        Schiedam Centrum          4191   Sprinter
# 2                NWL      Schiedam Nieuwland          4191   Sprinter
# 3                HIL                Hillegom          6395   Sprinter
# 4                NWL      Schiedam Nieuwland          4191   Sprinter
# ...              ...                     ...           ...        ...
# 5683044          ODB              Oudenbosch          5186   Sprinter
# 5683045          ZLW            Lage Zwaluwe          5186   Sprinter
# 5683046          ZDK       Zaandam Kogerveld          3384   Sprinter
# 5683047          BRD             Barendrecht         15184   Sprinter
# 5683048          ODB              Oudenbosch          5186   Sprinter
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  NS                 Hoofddorp                Hoofddorp
# 1                  NS        Rotterdam Centraal       Rotterdam Centraal
# 2                  NS        Rotterdam Centraal       Rotterdam Centraal
# 3                  NS           Leiden Centraal          Leiden Centraal
# 4                  NS        Rotterdam Centraal       Rotterdam Centraal
# ...               ...                       ...                      ...
# 5683044            NS         Den Haag Centraal        Den Haag Centraal
# 5683045            NS         Den Haag Centraal        Den Haag Centraal
# 5683046            NS       Hoorn Kersenboogerd      Hoorn Kersenboogerd
# 5683047            NS         Den Haag Centraal        Den Haag Centraal
# 5683048            NS         Den Haag Centraal        Den Haag Centraal
#
#         Train Departure Planned Train Departure Actual Train Delay
# 0          2016-06-30T21:58:00Z   2016-06-30T21:59:16Z     PT1M16S
# 1          2016-06-30T21:52:00Z   2016-06-30T22:02:50Z    PT10M50S
# 2          2016-06-30T21:49:00Z   2016-06-30T21:59:59Z    PT10M59S
# 3          2016-06-30T22:00:00Z   2016-06-30T22:01:23Z     PT1M23S
# 4          2016-06-30T21:49:00Z   2016-06-30T21:59:59Z    PT10M59S
# ...                         ...                    ...         ...
# 5683044    2016-07-31T21:58:00Z   2016-07-31T21:59:54Z     PT1M54S
# 5683045    2016-07-31T22:10:00Z   2016-07-31T22:11:03Z      PT1M3S
# 5683046    2016-07-31T22:01:00Z   2016-07-31T22:01:00Z        PT0S
# 5683047    2016-07-31T22:01:00Z   2016-07-31T22:01:00Z        PT0S
# 5683048    2016-07-31T21:58:00Z   2016-07-31T21:59:54Z     PT1M54S
#
# [5683049 rows x 10 columns]

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date, i also delete the str column i used for splitting the date and time
July['Train Departure Planned']=pd.to_datetime(July['Train Departure Planned'], format="%Y-%m-%dT%H:%M:%SZ")
July['Train Departure Planned1']=July['Train Departure Planned'].astype(str)
July[['DepartureDatePlanned','DepartureTimePlanned']]= July['Train Departure Planned1'].str.split(' ', expand = True)
July['DepartureDatePlanned']=pd.to_datetime(July['DepartureDatePlanned'])
July.drop('Train Departure Planned1', axis=1, inplace=True)
July
#then i make the depature time a time delta (Actually want to make it a normal time format)
July['DepartureTimePlanned'] = July.apply(lambda row: pd.to_datetime(row.DepartureDatePlanned).time(), axis=1)
print(July.info())
July
#then i basically do the same but for the actual departures
July['Train Departure Actual']=pd.to_datetime(July['Train Departure Actual'], format="%Y-%m-%dT%H:%M:%SZ")
July['Train Departure Actual1']=July['Train Departure Actual'].astype(str)
July[['DepartureDateActual','DepartureTimeActual']]= July['Train Departure Actual1'].str.split(' ', expand = True)
July['DepartureDateActual']=pd.to_datetime(July['DepartureDateActual'])
July.drop('Train Departure Actual1', axis=1, inplace=True)
July
#then i make the depature time a time delta (Actually want to make it a normal time format)
July['DepartureTimeActual'] = July.apply(lambda row: pd.to_datetime(row.DepartureDateActual).time(), axis=1)
print(July.info())
July
#Then i also put the delay in time delta format
July['Train Delay']=pd.to_timedelta(July['Train Delay'].str.strip())
July
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5683049 entries, 0 to 5683048
# Data columns (total 12 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     object
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
# dtypes: datetime64[ns](2), int64(1), object(9)
# memory usage: 520.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5683049 entries, 0 to 5683048
# Data columns (total 14 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     datetime64[ns]
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
#  12  DepartureDateActual        datetime64[ns]
#  13  DepartureTimeActual        object
# dtypes: datetime64[ns](4), int64(1), object(9)
# memory usage: 607.0+ MB
# None
#         Station Code            Station Name  Train Number Train Type  \
# 0               ASSP  Amsterdam Science Park          5882   Sprinter
# 1                SDM        Schiedam Centrum          4191   Sprinter
# 2                NWL      Schiedam Nieuwland          4191   Sprinter
# 3                HIL                Hillegom          6395   Sprinter
# 4                NWL      Schiedam Nieuwland          4191   Sprinter
# ...              ...                     ...           ...        ...
# 5683044          ODB              Oudenbosch          5186   Sprinter
# 5683045          ZLW            Lage Zwaluwe          5186   Sprinter
# 5683046          ZDK       Zaandam Kogerveld          3384   Sprinter
# 5683047          BRD             Barendrecht         15184   Sprinter
# 5683048          ODB              Oudenbosch          5186   Sprinter
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  N
NS        Rotterdam Centraal       Rotterdam Centraal
# 5692768            NS        Rotterdam Centraal       Rotterdam Centraal
#
#         Train Departure Planned Train Departure Actual Train Delay
# 0          2016-07-31T23:10:00Z   2016-07-31T23:10:00Z        PT0S
# 1          2016-07-31T23:10:00Z   2016-07-31T23:10:00Z        PT0S
# 2          2016-07-31T23:10:00Z   2016-07-31T23:10:00Z        PT0S
# 3          2016-07-31T23:10:00Z   2016-07-31T23:10:00Z        PT0S
# 4          2016-07-31T23:10:00Z   2016-07-31T23:10:00Z        PT0S
# ...                         ...                    ...         ...
# 5692764    2016-08-31T21:58:00Z   2016-08-31T22:03:00Z        PT5M
# 5692765    2016-08-31T22:04:00Z   2016-08-31T22:08:34Z     PT4M34S
# 5692766    2016-08-31T22:08:00Z   2016-08-31T22:12:16Z     PT4M16S
# 5692767    2016-08-31T22:16:00Z   2016-08-31T22:19:43Z     PT3M43S
# 5692768    2016-08-31T22:35:00Z   2016-08-31T22:36:28Z     PT1M28S
#
# [5692769 rows x 10 columns]

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date, i also delete the str column i used for splitting the date and time
August['Train Departure Planned']=pd.to_datetime(August['Train Departure Planned'], format="%Y-%m-%dT%H:%M:%SZ")
August['Train Departure Planned1']=August['Train Departure Planned'].astype(str)
August[['DepartureDatePlanned','DepartureTimePlanned']]= August['Train Departure Planned1'].str.split(' ', expand = True)
August['DepartureDatePlanned']=pd.to_datetime(August['DepartureDatePlanned'])
August.drop('Train Departure Planned1', axis=1, inplace=True)
August
#then i make the depature time a time delta (Actually want to make it a normal time format)
August['DepartureTimePlanned'] = August.apply(lambda row: pd.to_datetime(row.DepartureDatePlanned).time(), axis=1)
print(August.info())
August
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5692769 entries, 0 to 5692768
# Data columns (total 12 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     object
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
# dtypes: datetime64[ns](2), int64(1), object(9)
# memory usage: 521.2+ MB
# None
#         Station Code          Station Name  Train Number Train Type  \
# 0               NSCH      Bad Nieuweschans         37598  Stoptrein
# 1               HLMS   Haarlem Spaarnwoude         14882   Sprinter
# 2                HWD         Heerhugowaard          4082   Sprinter
# 3                VDW      Vlaardingen West          4197   Sprinter
# 4                SDM      Schiedam Centrum         15195   Sprinter
# ...              ...                   ...           ...        ...
# 5692764          ASD    Amsterdam Centraal         12682  Intercity
# 5692765          ASS  Amsterdam Sloterdijk         12682  Intercity
# 5692766         ASDL    Amsterdam Lelylaan         12682  Intercity
# 5692767          SHL      Schiphol Airport         12682  Intercity
# 5692768         LEDN       Leiden Centraal         12682  Intercity
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0              Arriva                 Groningen                Groningen
# 1                  NS        Amsterdam Centraal       Amsterdam Centraal
# 2                  NS                Den Helder               Den Helder
# 3                  NS        Rotterdam Centraal       Rotterdam Centraal
# 4                  NS                 Dordrecht                Dordrecht
# ...               ...                       ...                      ...
# 5692764            NS        Rotterdam Centraal       Rotterdam Centraal
# 5692765            NS        Rotterdam Centraal       Rotterdam Centraal
# 5692766            NS        Rotterdam Centraal       Rotterdam Centraal
# 5692767            NS        Rotterdam Centraal       Rotterdam Centraal
# 5692768            NS        Rotterdam Centraal       Rotterdam Centraal
#
#         Train Departure Planned Train Departure Actual Train Delay  \
# 0           2016-07-31 23:10:00   2016-07-31T23:10:00Z        PT0S
# 1           2016-07-31 23:10:00   2016-07-31T23:10:00Z        PT0S
# 2           2016-07-31 23:10:00   2016-07-31T23:10:00Z        PT0S
# 3           2016-07-31 23:10:00   2016-07-31T23:10:00Z        PT0S
# 4           2016-07-31 23:10:00   2016-07-31T23:10:00Z        PT0S
# ...                         ...                    ...         ...
# 5692764     2016-08-31 21:58:00   2016-08-31T22:03:00Z        PT5M
# 5692765     2016-08-31 22:04:00   2016-08-31T22:08:34Z     PT4M34S
# 5692766     2016-08-31 22:08:00   2016-08-31T22:12:16Z     PT4M16S
# 5692767     2016-08-31 22:16:00   2016-08-31T22:19:43Z     PT3M43S
# 5692768     2016-08-31 22:35:00   2016-08-31T22:36:28Z     PT1M28S
#
#         DepartureDatePlanned DepartureTimePlanned
# 0                 2016-07-31             00:00:00
# 1                 2016-07-31             00:00:00
# 2                 2016-07-31             00:00:00
# 3                 2016-07-31             00:00:00
# 4                 2016-07-31             00:00:00
# ...                      ...                  ...
# 5692764           2016-08-31             00:00:00
# 5692765           2016-08-31             00:00:00
# 5692766           2016-08-31             00:00:00
# 5692767           2016-08-31             00:00:00
# 5692768           2016-08-31             00:00:00
#
# [5692769 rows x 12 columns]

# %%
#then i do basically the same but for the actaul departures
August['Train Departure Actual']=pd.to_datetime(August['Train Departure Actual'], format="%Y-%m-%dT%H:%M:%SZ")
August['Train Departure Actual1']=August['Train Departure Actual'].astype(str)
August[['DepartureDateActual','DepartureTimeActual']]= August['Train Departure Actual1'].str.split(' ', expand = True)
August['DepartureDateActual']=pd.to_datetime(August['DepartureDateActual'])
August.drop('Train Departure Actual1', axis=1, inplace=True)
August
August['DepartureTimeActual'] = August.apply(lambda row: pd.to_datetime(row.DepartureDateActual).time(), axis=1)
print(August.info())
August
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5692769 entries, 0 to 5692768
# Data columns (total 14 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     datetime64[ns]
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
#  12  DepartureDateActual        datetime64[ns]
#  13  DepartureTimeActual        object
# dtypes: datetime64[ns](4), int64(1), object(9)
# memory usage: 608.1+ MB
# None
#         Station Code          Station Name  Train Number Train Type  \
# 0               NSCH      Bad Nieuweschans         37598  Stoptrein
# 1               HLMS   Haarlem Spaarnwoude         14882   Sprinter
# 2                HWD         Heerhugowaard          4082   Sprinter
# 3                VDW      Vlaardingen West          4197   Sprinter
# 4                SDM      Schiedam Centrum         15195   Sprinter
# ...              ...                   ...           ...        ...
# 5692764          ASD    Amsterdam Centraal         12682  Intercity
# 5692765          ASS  Amsterdam Sloterdijk         12682  Intercity
# 5692766         ASDL    Amsterdam Lelylaan         12682  Intercity
# 5692767          SHL      Schiphol Airport         12682  Intercity
# 5692768         LEDN       Leiden Centraal         12682  Intercity
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0              Arriva                 Groningen                Groningen
# 1                  NS        Amsterdam Centraal       Amsterdam Centraal
# 2                  NS                Den Helder               Den Helder
# 3                  NS        Rotterdam Centraal       Rotterdam Centraal
# 4                  NS                 Dordrecht                Dordrecht
# ...               ...                       ...                      ...
# 5692764            NS        Rotterdam Centraal       Rotterdam Centraal
# 5692765            NS        Rotterdam Centraal       Rotterdam Centraal
# 5692766            NS        Rotterdam Centraal       Rotterdam Centraal
# 5692767            NS        Rotterdam Centraal       Rotterdam Centraal
# 5692768            NS        Rotterdam Centraal       Rotterdam Centraal
#
#         Train Departure Planned Train Departure Actual Train Delay  \
# 0           2016-07-31 23:10:00    2016-07-31 23:10:00        PT0S
# 1           2016-07-31 23:10:00    2016-07-31 23:10:00        PT0S
# 2           2016-07-31 23:10:00    2016-07-31 23:10:00        PT0S
# 3           2016-07-31 23:10:00    2016-07-31 23:10:00        PT0S
# 4           2016-07-31 23:10:00    2016-07-31 23:10:00        PT0S
# ...                         ...                    ...         ...
# 5692764     2016-08-31 21:58:00    2016-08-31 22:03:00        PT5M
# 5692765     2016-08-31 22:04:00    2016-08-31 22:08:34     PT4M34S
# 5692766     2016-08-31 22:08:00    2016-08-31 22:12:16     PT4M16S
# 5692767     2016-08-31 22:16:00    2016-08-31 22:19:43     PT3M43S
# 5692768     2016-08-31 22:35:00    2016-08-31 22:36:28     PT1M28S
#
#         DepartureDatePlanned DepartureTimePlanned DepartureDateActual  \
# 0                 2016
#
#         DepartureTimeActual
# 0                  00:00:00
# 1                  00:00:00
# 2                  00:00:00
# 3                  00:00:00
# 4                  00:00:00
# ...                     ...
# 5692764            00:00:00
# 5692765            00:00:00
# 5692766            00:00:00
# 5692767            00:00:00
# 5692768            00:00:00
#
# [5692769 rows x 14 columns]

# %%
September=pd.read_csv('September.csv')
September.drop('Unnamed: 0',axis=1,inplace=True)
September.info()
September
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5697591 entries, 0 to 5697590
# Data columns (total 10 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    object
#  8   Train Departure Actual     object
#  9   Train Delay                object
# dtypes: int64(1), object(9)
# memory usage: 434.7+ MB
#         Station Code         Station Name  Train Number Train Type  \
# 0               HLMS  Haarlem Spaarnwoude         14882   Sprinter
# 1                 BV            Beverwijk         14895   Sprinter
# 2               NSCH     Bad Nieuweschans         37598  Stoptrein
# 3                ZVT    Zandvoort aan Zee          5480   Sprinter
# 4               HWZB   Halfweg-Zwanenburg          5478   Sprinter
# ...              ...                  ...           ...        ...
# 5697586         ALMB        Almere Buiten          4387   Sprinter
# 5697587            O                  Oss          3686  Intercity
# 5697588         KPNZ          Kampen Zuid          4688   Sprinter
# 5697589          CVM           Chevremont         32088  Stoptrein
# 5697590          KRD     Kerkrade Centrum         32088  Stoptrein
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  NS        Amsterdam Centraal       Amsterdam Centraal
# 1                  NS                   Alkmaar                  Alkmaar
# 2              Arriva                 Groningen                Groningen
# 3                  NS                   Haarlem                  Haarlem
# 4                  NS        Amsterdam Centraal       Amsterdam Centraal
# ...               ...                       ...                      ...
# 5697586            NS       Almere Oostvaarders      Almere Oostvaarders
# 5697587            NS           Arnhem Centraal          Arnhem Centraal
# 5697588            NS          Lelystad Centrum         Lelystad Centrum
# 5697589        Veolia                Maastricht               Maastricht
# 5697590        Veolia                Maastricht               Maastricht
#
#         Train Departure Planned Train Departure Actual Train Delay
# 0          2016-08-31T23:10:00Z   2016-08-31T23:10:00Z        PT0S
# 1          2016-08-31T23:10:00Z   2016-08-31T23:10:00Z        PT0S
# 2          2016-08-31T23:10:00Z   2016-08-31T23:10:00Z        PT0S
# 3          2016-08-31T21:59:00Z   2016-08-31T21:59:00Z        PT0S
# 4          2016-08-31T21:59:00Z   2016-08-31T21:59:00Z        PT0S
# ...                         ...                    ...         ...
# 5697586    2016-09-30T22:01:00Z   2016-09-30T22:01:00Z        PT0S
# 5697587    2016-09-30T21:56:00Z   2016-09-30T22:01:31Z     PT5M31S
# 5697588    2016-09-30T22:05:00Z   2016-09-30T22:06:25Z     PT1M25S
# 5697589    2016-09-30T22:01:00Z   2016-09-30T22:01:00Z        PT0S
# 5697590    2016-09-30T21:59:00Z   2016-09-30T21:59:00Z        PT0S
#
# [5697591 rows x 10 columns]

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date, i also delete the str column i used for splitting the date and time
September['Train Departure Planned']=pd.to_datetime(September['Train Departure Planned'], format="%Y-%m-%dT%H:%M:%SZ")
September['Train Departure Planned1']=September['Train Departure Planned'].astype(str)
September[['DepartureDatePlanned','DepartureTimePlanned']]= September['Train Departure Planned1'].str.split(' ', expand = True)
September['DepartureDatePlanned']=pd.to_datetime(September['DepartureDatePlanned'])
September.drop('Train Departure Planned1', axis=1, inplace=True)
September
#then i make the depature time a time delta (Actually want to make it a normal time format)
September['DepartureTimePlanned'] = September.apply(lambda row: pd.to_datetime(row.DepartureDatePlanned).time(), axis=1)
print(September.info())
September
#then i basically do the same but for the actual departures
September['Train Departure Actual']=pd.to_datetime(September['Train Departure Actual'], format="%Y-%m-%dT%H:%M:%SZ")
September['Train Departure Actual1']=September['Train Departure Actual'].astype(str)
September[['DepartureDateActual','DepartureTimeActual']]= September['Train Departure Actual1'].str.split(' ', expand = True)
September['DepartureDateActual']=pd.to_datetime(September['DepartureDateActual'])
September.drop('Train Departure Actual1', axis=1, inplace=True)
September
#then i make the depature time a time delta (Actually want to make it a normal time format)
September['DepartureTimeActual'] = September.apply(lambda row: pd.to_datetime(row.DepartureDateActual).time(), axis=1)
print(September.info())
September
#Then i also put the delay in time delta format
September['Train Delay']=pd.to_timedelta(September['Train Delay'].str.strip())
September
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5697591 entries, 0 to 5697590
# Data columns (total 12 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     object
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
# dtypes: datetime64[ns](2), int64(1), object(9)
# memory usage: 521.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5697591 entries, 0 to 5697590
# Data columns (total 14 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     datetime64[ns]
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
#  12  DepartureDateActual        datetime64[ns]
#  13  DepartureTimeActual        object
# dtypes: datetime64[ns](4), int64(1), object(9)
# memory usage: 608.6+ MB
# None
#         Station Code         Station Name  Train Number Train Type  \
# 0               HLMS  Haarlem Spaarnwoude         14882   Sprinter
# 1                 BV            Beverwijk         14895   Sprinter
# 2               NSCH     Bad Nieuweschans         37598  Stoptrein
# 3                ZVT    Zandvoort aan Zee          5480   Sprinter
# 4               HWZB   Halfweg-Zwanenburg          5478   Sprinter
# ...              ...                  ...           ...        ...
# 5697586         ALMB        Almere Buiten          4387   Sprinter
# 5697587            O                  Oss          3686  Intercity
# 5697588         KPNZ          Kampen Zuid          4688   Sprinter
# 5697589          CVM           Chevremont         32088  Stoptrein
# 5697590          KRD     Kerkrade Centrum         32088  Stoptrein
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  NS        Amsterdam Centraal       Amsterdam Centraal
# 1                  NS                   Alkmaar                  Alkmaar
# 2              Arriva                 Groningen                Groningen
# 3                  NS                   Haarlem                  Haarlem
# 4                  NS        Amsterdam Centraal       Amsterdam Centraal
# ...               ...                       ...                      ...
# 5697586            NS       Almere Oostvaarders      Almere Oostvaarders
# 5697587            NS           Arnhem Centraal          Arnhem Centraal
# 5697588            NS          Lelystad Centrum         Lelystad Centrum
# 5697589        Veolia                Maastricht               Maastricht
# 5697590        Veolia                Maastricht               Maastricht
#
#         Train Departure Planned Train Departure Actual     Train Delay  \
# 0           2016-08-31 23:10:00    2016-08-31 23:10:00 0 days 00:00:00
# 1           2016-08-31 23:10:00    2016-08-31 23:10:00 0 days 00:00:00
# 2           2016-08-31 23:10:00    2016-08-31 23:10:00 0 days 00:00:00
# 3           2016-08-31 21:59:00    2016-08-31 21:59:00 0 days 00:00:00
# 4           2016-08-31 21:59:00    2016-08-31 21:59:00 0 days 00:00:00
# ...                         ...                    ...             ...
# 5697586     2016-09-30 22:01:00    2016-09-30 22:01:00 0 days 00:00:00
# 5697587     2016-09-30 21:56:00    2016-09-30 22:01:31 0 days 00:05:31
# 5697588     2016-09-30 22:05:00    2016-09-30 22:06:25 0 days 00:01:25
# 5697589     2016-09-30 22:01:00    2016-09-30 22:01:00 0 days 00:00:00
# 5697590     2016-09-30 21:59:00    2016-09-30 21:59:00 0 days 00:00:00
#
#         DepartureDatePlanned DepartureTimePlanned DepartureDateActual  \
# 0                 2016-08-31             00:00:00          2016-08-31
# 1                 2016-08-31             00:00:00          2016-08-31
# 2                 2016-08-31             00:00:00          2016-08-31
# 3                 2016-08-31             00:00:00          2016-08-31
# 4                 2016-08-31             00:00:00          2016-08-31
# ...                      ...                  ...                 ...
# 5697586           2016-09-30             00:00:00          2016-09-30
# 5697587           2016-09-30             00:00:00          2016-09-30
# 5697588           2016-09-30             00:00:00          2016-09-30
# 5697589           2016-09-30             00:00:00          2016-09-30
# 5697590           2016-09-30             00:00:00          2016-09-30
#
#         DepartureTimeActual
# 0                  00:00:00
# 1                  00:00:00
# 2                  00:00:00
# 3                  00:00:00
# 4                  00:00:00
# ...                     ...
# 5697586            00:00:00
# 5697587            00:00:00
# 5697588            00:00:00
# 5697589            00:00:00
# 5697590            00:00:00
#
# [5697591 rows x 14 columns]

# %%
October=pd.read_csv('October.csv')
October.drop('Unnamed: 0',axis=1,inplace=True)
October.info()
October
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5805596 entries, 0 to 5805595
# Data columns (total 10 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    object
#  8   Train Departure Actual     object
#  9   Train Delay                object
# dtypes: int64(1), object(9)
# memory usage: 442.9+ MB
#         Station Code          Station Name  Train Number Train Type  \
# 0                 BV             Beverwijk         14895   Sprinter
# 1                VDW      Vlaardingen West          4197   Sprinter
# 2               GERP  Groningen Europapark          9196   Sprinter
# 3               NSCH      Bad Nieuweschans         37598  Stoptrein
# 4               HLMS   Haarlem Spaarnwoude         14882   Sprinter
# ...              ...                   ...           ...        ...
# 5805591           GS                  Goes          2672  Intercity
# 5805592          LLS      Lelystad Centrum          4685   Sprinter
# 5805593           GS                  Goes          2672  Intercity
# 5805594           OT            Oisterwijk          5288   Sprinter
# 5805595           AH       Arnhem Centraal          3085  Intercity
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  NS                   Alkmaar                  Alkmaar
# 1                  NS        Rotterdam Centraal       Rotterdam Centraal
# 2                  NS                     Assen                    Assen
# 3              Arriva                 Groningen                Groningen
# 4                  NS        Amsterdam Centraal       Amsterdam Centraal
# ...               ...                       ...                      ...
# 5805591            NS                Vlissingen               Vlissingen
# 5805592            NS                    Zwolle                   Zwolle
# 5805593            NS                Vlissingen               Vlissingen
# 5805594            NS      Tilburg Universiteit     Tilburg Universiteit
# 5805595            NS                  Nijmegen                 Nijmegen
#
#         Train Departure Planned Train Departure Actual Train Delay
# 0          2016-09-30T23:10:00Z   2016-09-30T23:10:00Z        PT0S
# 1          2016-09-30T23:10:00Z   2016-09-30T23:10:00Z        PT0S
# 2          2016-09-30T23:10:00Z   2016-09-30T23:10:00Z        PT0S
# 3          2016-09-30T23:10:00Z   2016-09-30T23:10:00Z        PT0S
# 4          2016-09-30T23:10:00Z   2016-09-30T23:10:00Z        PT0S
# ...                         ...                    ...         ...
# 5805591    2016-10-31T23:02:00Z   2016-10-31T23:02:00Z        PT0S
# 5805592    2016-10-31T23:05:00Z   2016-10-31T23:05:00Z        PT0S
# 5805593    2016-10-31T23:02:00Z   2016-10-31T23:02:00Z        PT0S
# 5805594    2016-10-31T22:58:00Z   2016-10-31T22:59:41Z     PT1M41S
# 5805595    2016-10-31T23:04:00Z   2016-10-31T23:04:00Z        PT0S
#
# [5805596 rows x 10 columns]

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date, i also delete the str column i used for splitting the date and time
October['Train Departure Planned']=pd.to_datetime(October['Train Departure Planned'], format="%Y-%m-%dT%H:%M:%SZ")
October['Train Departure Planned1']=October['Train Departure Planned'].astype(str)
October[['DepartureDatePlanned','DepartureTimePlanned']]= October['Train Departure Planned1'].str.split(' ', expand = True)
October['DepartureDatePlanned']=pd.to_datetime(October['DepartureDatePlanned'])
October.drop('Train Departure Planned1', axis=1, inplace=True)
October
#then i make the depature time a time delta (Actually want to make it a normal time format)
October['DepartureTimePlanned'] = October.apply(lambda row: pd.to_datetime(row.DepartureDatePlanned).time(), axis=1)
print(October.info())
October
#then i basically do the same but for the actual departures
October['Train Departure Actual']=pd.to_datetime(October['Train Departure Actual'], format="%Y-%m-%dT%H:%M:%SZ")
October['Train Departure Actual1']=October['Train Departure Actual'].astype(str)
October[['DepartureDateActual','DepartureTimeActual']]= October['Train Departure Actual1'].str.split(' ', expand = True)
October['DepartureDateActual']=pd.to_datetime(October['DepartureDateActual'])
October.drop('Train Departure Actual1', axis=1, inplace=True)
October
October['DepartureTimeActual'] = October.apply(lambda row: pd.to_datetime(row.DepartureDateActual).time(), axis=1)
print(October.info())
October
#Then i also put the delay in time delta format
October['Train Delay']=pd.to_timedelta(October['Train Delay'].str.strip())
October
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5805596 entries, 0 to 5805595
# Data columns (total 12 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     object
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
# dtypes: datetime64[ns](2), int64(1), object(9)
# memory usage: 531.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5805596 entries, 0 to 5805595
# Data columns (total 14 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     datetime64[ns]
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
#  12  DepartureDateActual        datetime64[ns]
#  13  DepartureTimeActual        object
# dtypes: datetime64[ns](4), int64(1), object(9)
# memory usage: 620.1+ MB
# None
#         Station Code          Station Name  Train Number Train Type  \
# 0                 BV             Beverwijk         14895   Sprinter
# 1                VDW      Vlaardingen West          4197   Sprinter
# 2               GERP  Groningen Europapark          9196   Sprinter
# 3               NSCH      Bad Nieuweschans         37598  Stoptrein
# 4               HLMS   Haarlem Spaarnwoude         14882   Sprinter
# ...              ...                   ...           ...        ...
# 5805591           GS                  Goes          2672  Intercity
# 5805592          LLS      Lelystad Centrum          4685   Sprinter
# 5805593           GS                  Goes          2672  Intercity
# 5805594           OT            Oisterwijk          5288   Sprinter
# 5805595           AH       Arnhem Centraal          3085  Intercity
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  NS                   Alkmaar                  Alkmaar
# 1                  NS        Rotterdam Centraal       Rotterdam Centraal
# 2                  NS                     Assen                    Assen
# 3              Arriva                 Groningen                Groningen
# 4                  NS        Amsterdam Centraal       Amsterdam Centraal
# ...               ...                       ...                      ...
# 5805591            NS                Vlissingen               Vlissingen
# 5805592            NS                    Zwolle                   Zwolle
# 5805593            NS                Vlissingen               Vlissingen
# 5805594            NS      Tilburg Universiteit     Tilburg Universiteit
# 5805595            NS                  Nijmegen                 Nijmegen
#
#         Train Departure Planned Train Departure Actual     Train Delay  \
# 0           2016-09-30 23:10:00    2016-09-30 23:10:00 0 days 00:00:00
# 1           2016-09-30 23:10:00    2016-09-30 23:10:00 0 days 00:00:00
# 2           2016-09-30 23:10:00    2016-09-30 23:10:00 0 days 00:00:00
# 3           2016-09-30 23:10:00    2016-09-30 23:10:00 0 days 00:00:00
# 4           2016-09-30 23:10:00    2016-09-30 23:10:00 0 days 00:00:00
# ...                         ...                    ...             ...
# 5805591     2016-10-31 23:02:00    2016-10-31 23:02:00 0 days 00:00:00
# 5805592     2016-10-31 23:05:00    2016-10-31 23:05:00 0 days 00:00:00
# 5805593     2016-10-31 23:02:00    2016-10-31 23:02:00 0 days 00:00:00
# 5805594     2016-10-31 22:58:00    2016-10-31 22:59:41 0 days 00:01:41
# 5805595     2016-10-31 23:04:00    2016-10-31 23:04:00 0 days 00:00:00
#
#         DepartureDatePlanned DepartureTimePlanned DepartureDateActual  \
# 0                 2016-09-30             00:00:00          2016-09-30
# 1                 2016-09-30             00:00:00          2016-09-30
# 2                 2016-09-30             00:00:00          2016-09-30
# 3                 2016-09-30             00:00:00          2016-09-30
# 4                 2016-09-30             00:00:00          2016-09-30
# ...                      ...                  ...                 ...
# 5805591           2016-10-31             00:00:00          2016-10-31
# 5805592           2016-10-31             00:00:00          2016-10-31
# 5805593           2016-10-31             00:00:00          2016-10-31
# 5805594           2016-10-31             00:00:00          2016-10-31
# 5805595           2016-10-31             00:00:00          2016-10-31
#
#         DepartureTimeActual
# 0                  00:00:00
# 1                  00:00:00
# 2                  00:00:00
# 3                  00:00:00
# 4                  00:00:00
# ...                     ...
# 5805591            00:00:00
# 5805592            00:00:00
# 5805593            00:00:00
# 5805594            00:00:00
# 5805595            00:00:00
#
# [5805596 rows x 14 columns]

# %%
November=pd.read_csv('November.csv')
November.drop('Unnamed: 0',axis=1,inplace=True)
November.info()
November
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6252976 entries, 0 to 6252975
# Data columns (total 10 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    object
#  8   Train Departure Actual     object
#  9   Train Delay                object
# dtypes: int64(1), object(9)
# memory usage: 477.1+ MB
#         Station Code           Station Name  Train Number Train Type  \
# 0                VDW       Vlaardingen West          4197   Sprinter
# 1                SDM       Schiedam Centrum         15195   Sprinter
# 2               NSCH       Bad Nieuweschans         37598  Stoptrein
# 3               HLMS    Haarlem Spaarnwoude         14882   Sprinter
# 4                GDM           Geldermalsen          6086   Sprinter
# ...              ...                    ...           ...        ...
# 6252971           WL                   Wehl         30988  Stoptrein
# 6252972         DVNK                De Vink          5791   Sprinter
# 6252973          DVD           Duivendrecht          4082   Sprinter
# 6252974         ASDM  Amsterdam Muiderpoort          4082   Sprinter
# 6252975          ASA       Amsterdam Amstel          4082   Sprinter
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  NS        Rotterdam Centraal       Rotterdam Centraal
# 1                  NS                 Dordrecht                Dordrecht
# 2              Arriva                 Groningen                Groningen
# 3                  NS        Amsterdam Centraal       Amsterdam Centraal
# 4                  NS          Utrecht Centraal         Utrecht Centraal
# ...               ...                       ...                      ...
# 6252971        Arriva           Arnhem Centraal          Arnhem Centraal
# 6252972            NS               Diemen Zuid              Diemen Zuid
# 6252973            NS                Den Helder               Den Helder
# 6252974            NS                Den Helder               Den Helder
# 6252975            NS                Den Helder               Den Helder
#
#         Train Departure Planned Train Departure Actual Train Delay
# 0          2016-11-01T00:10:00Z   2016-11-01T00:10:00Z        PT0S
# 1          2016-11-01T00:10:00Z   2016-11-01T00:10:00Z        PT0S
# 2          2016-11-01T00:10:00Z   2016-11-01T00:10:00Z        PT0S
# 3          2016-11-01T00:10:00Z   2016-11-01T00:10:00Z        PT0S
# 4          2016-10-31T23:07:00Z   2016-10-31T23:07:00Z        PT0S
# ...                         ...                    ...         ...
# 6252971    2016-11-30T23:01:00Z   2016-11-30T23:01:11Z       PT11S
# 6252972    2016-11-30T23:01:00Z   2016-11-30T23:01:00Z        PT0S
# 6252973    2016-11-30T22:59:00Z   2016-11-30T22:59:38Z       PT38S
# 6252974    2016-11-30T23:06:00Z   2016-11-30T23:06:05Z        PT5S
# 6252975    2016-11-30T23:03:00Z   2016-11-30T23:03:19Z       PT19S
#
# [6252976 rows x 10 columns]

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date, i also delete the str column i used for splitting the date and time
November['Train Departure Planned']=pd.to_datetime(November['Train Departure Planned'], format="%Y-%m-%dT%H:%M:%SZ")
November['Train Departure Planned1']=November['Train Departure Planned'].astype(str)
November[['DepartureDatePlanned','DepartureTimePlanned']]= November['Train Departure Planned1'].str.split(' ', expand = True)
November['DepartureDatePlanned']=pd.to_datetime(November['DepartureDatePlanned'])
November.drop('Train Departure Planned1', axis=1, inplace=True)
November
#then i make the depature time a time delta (Actually want to make it a normal time format)
November['DepartureTimePlanned'] = November.apply(lambda row: pd.to_datetime(row.DepartureDatePlanned).time(), axis=1)
print(November.info())
November
#then i basically do the same but for the actual departures
November['Train Departure Actual']=pd.to_datetime(November['Train Departure Actual'], format="%Y-%m-%dT%H:%M:%SZ")
November['Train Departure Actual1']=November['Train Departure Actual'].astype(str)
November[['DepartureDateActual','DepartureTimeActual']]= November['Train Departure Actual1'].str.split(' ', expand = True)
November['DepartureDateActual']=pd.to_datetime(November['DepartureDateActual'])
November.drop('Train Departure Actual1', axis=1, inplace=True)
November
#then i make the depature time a time delta (Actually want to make it a normal time format)
November['DepartureTimeActual'] = November.apply(lambda row: pd.to_datetime(row.DepartureDateActual).time(), axis=1)
print(November.info())
November
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6252976 entries, 0 to 6252975
# Data columns (total 12 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     object
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
# dtypes: datetime64[ns](2), int64(1), object(9)
# memory usage: 572.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6252976 entries, 0 to 6252975
# Data columns (total 14 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               int64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     datetime64[ns]
#  9   Train Delay                object
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
#  12  DepartureDateActual        datetime64[ns]
#  13  DepartureTimeActual        object
# dtypes: datetime64[ns](4), int64(1), object(9)
# memory usage: 667.9+ MB
# None
#         Station Code           Station Name  Train Number Train Type  \
# 0                VDW       Vlaardingen West          4197   Sprinter
# 1                SDM       Schiedam Centrum         15195   Sprinter
# 2               NSCH       Bad Nieuweschans         37598  Stoptrein
# 3               HLMS    Haarlem Spaarnwoude         14882   Sprinter
# 4                GDM           Geldermalsen          6086   Sprinter
# ...              ...                    ...           ...        ...
# 6252971           WL                   Wehl         30988  Stoptrein
# 6252972         DVNK                De Vink          5791   Sprinter
# 6252973          DVD           Duivendrecht          4082   Sprinter
# 6252974         ASDM  Amsterdam Muiderpoort          4082   Sprinter
# 6252975          ASA       Amsterdam Amstel          4082   Sprinter
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  NS        Rotterdam Centraal       Rotterdam Centraal
# 1                  NS                 Dordrecht                Dordrecht
# 2              Arriva                 Groningen                Groningen
# 3                  NS        Amsterdam Centraal       Amsterdam Centraal
# 4                  NS          Utrecht Centraal         Utrecht Centraal
# ...               ...                       ...                      ...
# 6252971        Arriva           Arnhem Centraal          Arnhem Centraal
# 6252972            NS               Diemen Zuid              Diemen Zuid
# 6252973            NS                Den Helder               Den Helder
# 6252974            NS                Den Helder               Den Helder
# 6252975            NS                Den Helder               Den Helder
#
#         Train Departure Planned Train Departure Actual Train Delay  \
# 0           2016-11-01 00:10:00    2016-11-01 00:10:00        PT0S
# 1           2016-11-01 00:10:00    2016-11-01 00:10:00        PT0S
# 2           2016-11-01 00:10:00    2016-11-01 00:10:00        PT0S
# 3           2016-11-01 00:10:00    2016-11-01 00:10:00        PT0S
# 4           2016-10-31 23:07:00    2016-10-31 23:07:00        PT0S
# ...                         ...                    ...         ...
# 6252971     2016-11-30 23:01:00    2016-11-30 23:01:11       PT11S
# 6252972     2016-11-30 23:01:00    2016-11-30 23:01:00        PT0S
# 6252973     2016-11-30 22:59:00    2016-11-30 22:59:38       PT38S
# 6252974     2016-11-30 23:06:00    2016-11-30 23:06:05        PT5S
# 6252975     2016-11-30 23:03:00    2016-11-30 23:03:19       PT19S
#
#         DepartureDatePlanned DepartureTimePlanned DepartureDateActual  \
# 0                 2016-11-01             00:00:00          2016-11-01
# 1                 2016-11-01             00:00:00          2016-11-01
# 2                 2016-11-01             00:00:00          2016-11-01
# 3                 2016-11-01             00:00:00          2016-11-01
# 4                 2016-10-31             00:00:00          2016-10-31
# ...                      ...                  ...                 ...
# 6252971           2016-11-30             00:00:00          2016-11-30
# 6252972           2016-11-30             00:00:00          2016-11-30
# 6252973           2016-11-30             00:00:00          2016-11-30
# 6252974           2016-11-30             00:00:00          2016-11-30
# 6252975           2016-11-30             00:00:00          2016-11-30
#
#         DepartureTimeActual
# 0                  00:00:00
# 1                  00:00:00
# 2                  00:00:00
# 3                  00:00:00
# 4                  00:00:00
# ...                     ...
# 6252971            00:00:00
# 6252972            00:00:00
# 6252973            00:00:00
# 6252974            00:00:00
# 6252975            00:00:00
#
# [6252976 rows x 14 columns]

# %%
#Then i also put the delay in time delta format
November['Train Delay']=pd.to_timedelta(November['Train Delay'].astype(str).str.strip())
November
# Out:
#         Station Code           Station Name  Train Number Train Type  \
# 0                VDW       Vlaardingen West          4197   Sprinter
# 1                SDM       Schiedam Centrum         15195   Sprinter
non-null  object
# dtypes: int64(1), object(9)
# memory usage: 93.5+ MB
#         Station Code           Station Name  Train Number Train Type  \
# 0               HLMS    Haarlem Spaarnwoude         14882   Sprinter
# 1                 BV              Beverwijk         14895   Sprinter
# 2               NSCH       Bad Nieuweschans         37598  Stoptrein
# 3                DVD           Duivendrecht          4082   Sprinter
# 4               ASDM  Amsterdam Muiderpoort          5889   Sprinter
# ...              ...                    ...           ...        ...
# 1225405          ASD     Amsterdam Centraal          1406  Intercity
# 1225406           DT                  Delft          1410  Intercity
# 1225407           GV            Den Haag HS          1414  Intercity
# 1225408         LEDN        Leiden Centraal          1409  Intercity
# 1225409           DT                  Delft          1410  Intercity
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  NS        Amsterdam Centraal       Amsterdam Centraal
# 1                  NS                   Alkmaar                  Alkmaar
# 2              Arriva                 Groningen                Groningen
# 3                  NS                Den Helder               Den Helder
# 4                  NS                Amersfoort               Amersfoort
# ...               ...                       ...                      ...
# 1225405            NS          Utrecht Centraal         Utrecht Centraal
# 1225406            NS          Utrecht Centraal         Utrecht Centraal
# 1225407            NS          Utrecht Centraal         Utrecht Centraal
# 1225408            NS        Rotterdam Centraal       Rotterdam Centraal
# 1225409            NS          Utrecht Centraal         Utrecht Centraal
#
#         Train Departure Planned Train Departure Actual Train Delay
# 0          2016-12-01T00:10:00Z   2016-12-01T00:10:00Z        PT0S
# 1          2016-12-01T00:10:00Z   2016-12-01T00:10:00Z        PT0S
# 2          2016-12-01T00:10:00Z   2016-12-01T00:10:00Z        PT0S
# 3          2016-11-30T22:59:00Z   2016-11-30T22:59:38Z       PT38S
# 4          2016-11-30T22:58:00Z   2016-11-30T23:00:02Z      PT2M2S
# ...                         ...                    ...         ...
# 1225405    2016-12-07T01:17:00Z   2016-12-07T01:17:00Z        PT0S
# 1225406    2016-12-07T01:14:00Z   2016-12-07T01:14:00Z        PT0S
# 1225407    2016-12-07T02:23:00Z   2016-12-07T02:23:00Z        PT0S
# 1225408    2016-12-07T02:24:00Z   2016-12-07T02:24:00Z        PT0S
# 1225409    2016-12-07T01:14:00Z   2016-12-07T01:14:00Z        PT0S
#
# [1225410 rows x 10 columns]

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date, i also delete the str column i used for splitting the date and time
December['Train Departure Planned']=pd.to_datetime(December['Train Departure Planned'], format="%Y-%m-%dT%H:%M:%SZ")
December['Train Departure Planned1']=December['Train Departure Planned'].astype(str)
December[['DepartureDatePlanned','DepartureTimePlanned']]= December['Train Departure Planned1'].str.split(' ', expand = True)
December['DepartureDatePlanned']=pd.to_datetime(December['DepartureDatePlanned'])
December.drop('Train Departure Planned1', axis=1, inplace=True)
December
#then i make the depature time a time delta (Actually want to make it a normal time format)
December['DepartureTimePlanned'] = December.apply(lambda row: pd.to_datetime(row.DepartureDatePlanned).time(), axis=1)
print(December.info())
December
#then i basically do the same but for the actual departures
December['Train Departure Actual']=pd.to_datetime(December['Train Departure Actual'], format="%Y-%m-%dT%H:%M:%SZ")
December['Train Departure Actual1']=December['Train Departure Actual'].astype(str)
December[['DepartureDateActual','DepartureTimeActual']]= December['Train Departure Actual1'].str.split(' ', expand = True)
December['DepartureDateActual']=pd.to_datetime(December['DepartureDateActual'])
December.drop('Train Departure Actual1', axis=1, inplace=True)
December
December['DepartureTimeActual'] = December.apply(lambda row: pd.to_datetime(row.DepartureDateActual).time(), axis=1)
print(December.info())
December
#Then i also put the delay in time delta format
December['Train Delay']=pd.to_timedelta(December['Train Delay'].str.strip())
December
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1225410 entries, 0 to 1225409
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Station Code               1223493 non-null  object
#  1   Station Name               1225410 non-null  object
#  2   Train Number               1225410 non-null  int64
#  3   Train Type                 1225410 non-null  object
#  4   Train Company              1225410 non-null  object
#  5   Train Destination Planned  1225410 non-null  object
#  6   Train Destination Actual   1225410 non-null  object
#  7   Train Departure Planned    1225410 non-null  datetime64[ns]
#  8   Train Departure Actual     1225410 non-null  object
#  9   Train Delay                1225410 non-null  object
#  10  DepartureDatePlanned       1225410 non-null  datetime64[ns]
#  11  DepartureTimePlanned       1225410 non-null  object
# dtypes: datetime64[ns](2), int64(1), object(9)
# memory usage: 112.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1225410 entries, 0 to 1225409
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Station Code               1223493 non-null  object
#  1   Station Name               1225410 non-null  object
#  2   Train Number               1225410 non-null  int64
#  3   Train Type                 1225410 non-null  object
#  4   Train Company              1225410 non-null  object
#  5   Train Destination Planned  1225410 non-null  object
#  6   Train Destination Actual   1225410 non-null  object
#  7   Train Departure Planned    1225410 non-null  datetime64[ns]
#  8   Train Departure Actual     1225410 non-null  datetime64[ns]
#  9   Train Delay                1225410 non-null  object
#  10  DepartureDatePlanned       1225410 non-null  datetime64[ns]
#  11  DepartureTimePlanned       1225410 non-null  object
#  12  DepartureDateActual        1225410 non-null  datetime64[ns]
#  13  DepartureTimeActual        1225410 non-null  object
# dtypes: datetime64[ns](4), int64(1), object(9)
# memory usage: 130.9+ MB
# None
#         Station Code           Station Name  Train Number Train Type  \
# 0               HLMS    Haarlem Spaarnwoude         14882   Sprinter
# 1                 BV              Beverwijk         14895   Sprinter
# 2               NSCH       Bad Nieuweschans         37598  Stoptrein
# 3                DVD           Duivendrecht          4082   Sprinter
# 4               ASDM  Amsterdam Muiderpoort          5889   Sprinter
# ...              ...                    ...           ...        ...
# 1225405          ASD     Amsterdam Centraal          1406  Intercity
# 1225406           DT                  Delft          1410  Intercity
# 1225407           GV            Den Haag HS          1414  Intercity
# 1225408         LEDN        Leiden Centraal          1409  Intercity
# 1225409           DT                  Delft          1410  Intercity
#
#         Train Company Train Destination Planned Train Destination Actual  \
# 0                  NS        Amsterdam Centraal       Amsterdam Centraal
# 1                  NS                   Alkmaar                  Alkmaar
# 2              Arriva                 Groningen                Groningen
# 3                  NS                Den Helder               Den Helder
# 4                  NS                Amersfoort               Amersfoort
# ...               ...                       ...                      ...
# 1225405            NS          Utrecht Centraal         Utrecht Centraal
# 1225406            NS          Utrecht Centraal         Utrecht Centraal
# 1225407            NS          Utrecht Centraal         Utrecht Centraal
# 1225408            NS        Rotterdam Centraal       Rotterdam Centraal
# 1225409            NS          Utrecht Centraal         Utrecht Centraal
#
# 59907702            NS        Rotterdam Centraal       Rotterdam Centraal
# 59907703            NS          Utrecht Centraal         Utrecht Centraal
#
#          Train Departure Planned Train Departure Actual Train Delay  \
# 0            2016-01-01 00:10:00    2016-01-01 00:10:00      0 days
# 1            2016-01-01 00:10:00    2016-01-01 00:10:00      0 days
# 2            2016-01-01 00:11:00    2016-01-01 00:11:00      0 days
# 3            2016-01-01 00:11:00    2016-01-01 00:11:00      0 days
# 4            2016-01-01 00:11:00    2016-01-01 00:11:00      0 days
# ...                          ...                    ...         ...
# 59907699     2016-12-07 01:17:00    2016-12-07 01:17:00      0 days
# 59907700     2016-12-07 01:14:00    2016-12-07 01:14:00      0 days
# 59907701     2016-12-07 02:23:00    2016-12-07 02:23:00      0 days
# 59907702     2016-12-07 02:24:00    2016-12-07 02:24:00      0 days
# 59907703     2016-12-07 01:14:00    2016-12-07 01:14:00      0 days
#
#          DepartureDatePlanned DepartureTimePlanned DepartureDateActual  \
# 0                  2016-01-01             00:00:00          2016-01-01
# 1                  2016-01-01             00:00:00          2016-01-01
# 2                  2016-01-01             00:00:00          2016-01-01
# 3                  2016-01-01             00:00:00          2016-01-01
# 4                  2016-01-01             00:00:00          2016-01-01
# ...                       ...                  ...                 ...
# 59907699           2016-12-07             00:00:00          2016-12-07
# 59907700           2016-12-07             00:00:00          2016-12-07
# 59907701           2016-12-07             00:00:00          2016-12-07
# 59907702           2016-12-07             00:00:00          2016-12-07
# 59907703           2016-12-07             00:00:00          2016-12-07
#
#          DepartureTimeActual
# 0                   00:00:00
# 1                   00:00:00
# 2                   00:00:00
# 3                   00:00:00
# 4                   00:00:00
# ...                      ...
# 59907699            00:00:00
# 59907700            00:00:00
# 59907701            00:00:00
# 59907702            00:00:00
# 59907703            00:00:00
#
# [59907704 rows x 14 columns]

# %%
TrainData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59907704 entries, 0 to 59907703
# Data columns (total 14 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Station Code               object
#  1   Station Name               object
#  2   Train Number               float64
#  3   Train Type                 object
#  4   Train Company              object
#  5   Train Destination Planned  object
#  6   Train Destination Actual   object
#  7   Train Departure Planned    datetime64[ns]
#  8   Train Departure Actual     datetime64[ns]
#  9   Train Delay                timedelta64[ns]
#  10  DepartureDatePlanned       datetime64[ns]
#  11  DepartureTimePlanned       object
#  12  DepartureDateActual        datetime64[ns]
#  13  DepartureTimeActual        object
# dtypes: datetime64[ns](4), float64(1), object(8), timedelta64[ns](1)
# memory usage: 6.2+ GB

# %% [markdown]
# ## Delays and max number of stops

# %%
#make the spaces in the column names _ so its easier to use
January.columns = [c.replace(' ', '_') for c in January.columns]

# %%
#calculate the max number of stops by counting the unique station names per ride + 1 for the final station
January['MaxNumberOfStops']=January.groupby(['Train_Destination_Planned', 'Train_Number'])['Station_Name'].transform('nunique')+1
January.sort_values(['Train_Destination_Planned','Train_Departure_Planned'])
#assumptions: the train numbers stays the same for the whole time and the destination planned is the end destinations
# Out:
#         Station_Code        Station_Name  Train_Number Train_Type  \
# 134               TB             Tilburg         21424  Intercity
# 672              EHV           Eindhoven          9618   Sprinter
# 2296             EHV           Eindhoven          9618   Sprinter
# 703              EHS  Eindhoven Strijp-S          9618   Sprinter
# 2378             EHS  Eindhoven Strijp-S          9618   Sprinter
# ...              ...                 ...           ...        ...
# 5454650          OST                Olst          3682  Intercity
# 5454652         KPNZ         Kampen Zuid          4685   Sprinter
# 5454777           HD          Harderwijk           587  Intercity
# 5455214           WZ               Wezep          5685   Sprinter
# 5455324           WH               Wijhe          3682  Intercity
#
#         Train_Company Train_Destination_Planned Train_Destination_Actual  \
# 134                NS          's-Hertogenbosch                  Tilburg
# 672                NS          's-Hertogenbosch         's-Hertogenbosch
# 2296               NS          's-Hertogenbosch         's-Hertogenbosch
# 703                NS          's-Hertogenbosch         's-Hertogenbosch
# 2378               NS          's-Hertogenbosch         's-Hertogenbosch
# ...               ...                       ...                      ...
# 5454650            NS                    Zwolle                   Zwolle
# 5454652            NS                    Zwolle                   Zwolle
# 5454777            NS                    Zwolle                   Zwolle
# 5455214            NS                    Zwolle                   Zwolle
# 5455324            NS                    Zwolle                   Zwolle
#
#         Train_Departure_Planned Train_Departure_Actual Train_Delay  \
# 134         2016-01-01 01:03:00    2016-01-01 01:03:00      0 days
# 672         2016-01-01 05:47:00    2016-01-01 05:47:00      0 days
# 2296        2016-01-01 05:47:00    2016-01-01 05:47:00      0 days
# 703         2016-01-01 05:50:00    2016-01-01 05:50:00      0 days
# 2378        2016-01-01 05:50:00    2016-01-01 05:50:00      0 days
# ...                         ...                    ...         ...
# 5454650     2016-01-31 23:24:00    2016-01-31 23:24:00      0 days
# 5454652     2016-01-31 23:24:00    2016-01-31 23:24:00      0 days
# 5454777     2016-01-31 23:25:00    2016-01-31 23:25:00      0 days
# 5455214     2016-01-31 23:29:00    2016-01-31 23:29:00      0 days
# 5455324     2016-01-31 23:30:00    2016-01-31 23:30:00      0 days
#
#         DepartureDatePlanned DepartureTimePlanned DepartureDateActual  \
# 134               2016-01-01             00:00:00          2016-01-01
# 672               2016-01-01             00:00:00          2016-01-01
# 2296              2016-01-01             00:00:00          2016-01-01
# 703               2016-01-01             00:00:00          2016-01-01
# 2378              2016-01-01             00:00:00          2016-01-01
# ...                      ...                  ...                 ...
# 5454650           2016-01-31             00:00:00          2016-01-31
# 5454652           2016-01-31             00:00:00          2016-01-31
# 5454777           2016-01-31             00:00:00          2016-01-31
# 5455214           2016-01-31             00:00:00          2016-01-31
# 5455324           2016-01-31             00:00:00          2016-01-31
#
#         DepartureTimeActual  MaxNumberOfStops
# 134                00:00:00                 2
# 672                00:00:00                 6
# 2296               00:00:00                 6
# 703                00:00:00                 6
# 2378               00:00:00                 6
# ...                     ...               ...
# 5454650            00:00:00                17
# 5454652            00:00:00                15
# 5454777            00:00:00                 8
# 5455214            00:00:00                15
# 5455324            00:00:00                17
#
# [5458998 rows x 15 columns]

# %%
# make the duration a number in seconds
January['Train_Delay'] = January.apply(lambda row: row.Train_Delay.total_seconds(), axis=1)

# %%
# scatter plot of delay against max number of stops
plt.figure(figsize=(9, 6))
plt.scatter(x=January['Train_Delay'], y=January['MaxNumberOfStops'])
plt.xlabel('Delay in seconds')
plt.xlabel('Max number of stops of a train ride')
plt.title('Delay vs Max number of stops')
# Out:
# Text(0.5, 1.0, 'Delay vs Max number of stops')

# %%
#distribution of the train delay in histograph
plt.hist(np.asarray(January.dropna().Train_Delay), 100, density=1);
plt.title('Distribution of delay in seconds')
# Out:
# Text(0.5, 1.0, 'Distribution of delay in seconds')

# %%
# distribution of the max number of stops in a histograph
plt.hist(np.asarray(January.dropna().MaxNumberOfStops), 100, density=1);
plt.title('Distribution of Max number of stops')
# Out:
# Text(0.5, 1.0, 'Distribution of Max number of stops')

# %%
#make a distribution plot where the max number of stops per train number and planned destination is only once in the dataset
MaxStops=January.groupby(['Train_Number','Train_Destination_Planned'])['MaxNumberOfStops'].mean()
MaxStops=pd.DataFrame(MaxStops)
plt.hist(np.asarray(MaxStops.dropna().MaxNumberOfStops), 100, density=1);
plt.title('Distribution of Max number of stops per train ride')
# Out:
# Text(0.5, 1.0, 'Distribution of Max number of stops per train ride')

# %% [markdown]
# ## Total delay

# %%
#First we get the Total delay per day in seconds
import matplotlib.pyplot as plt
TotalDelayDay = January.groupby('DepartureDateActual')['Train_Delay'].sum().reset_index()
TotalDelayDay
# Out:
#    DepartureDateActual  Train_Delay
# 0           2015-12-31       1364.0
# 1           2016-01-01    6026458.0
# 2           2016-01-02    5795138.0
# 3           2016-01-03   13356435.0
# 4           2016-01-04   15561928.0
# 5           2016-01-05   15529623.0
# 6           2016-01-06   12811218.0
# 7           2016-01-07   14615727.0
# 8           2016-01-08   16172435.0
# 9           2016-01-09    7565149.0
# 10          2016-01-10    7081794.0
# 11          2016-01-11   13847459.0
# 12          2016-01-12   15076467.0
# 13          2016-01-13   13214645.0
# 14          2016-01-14   17944677.0
# 15          2016-01-15   19639562.0
# 16          2016-01-16    7065761.0
# 17          2016-01-17   14092599.0
# 18          2016-01-18   20103828.0
# 19          2016-01-19   17360928.0
# 20          2016-01-20   13468934.0
# 21          2016-01-21   21207483.0
# 22          2016-01-22   15765810.0
# 23          2016-01-23    7724723.0
# 24          2016-01-24    7907794.0
# 25          2016-01-25   11382446.0
# 26          2016-01-26   14633476.0
# 27          2016-01-27   13438172.0
# 28          2016-01-28   11546612.0
# 29          2016-01-29   13488111.0
# 30          2016-01-30    8013466.0
# 31          2016-01-31   10078672.0
# 32          2016-02-01      39081.0

# %%
#Then we visualise it with bargraph
plt.figure(figsize=(16,10))
plt.bar(TotalDelayDay['DepartureDateActual'],TotalDelayDay['Train_Delay'])
# Out:
# <BarContainer object of 33 artists>

# %%
#average total delay per weekday (group by weekday and calculate avg delay)
#Firt we extract the day of the week in a new column
January['weekday'] = January['DepartureDateActual'].dt.dayofweek
January
# Out:
#         Station_Code            Station_Name  Train_Number Train_Type  \
# 0               HLMS     Haarlem Spaarnwoude         14882   Sprinter
# 1               NSCH        Bad Nieuweschans         37598  Stoptrein
# 2                DVD            Duivendrecht          7495   Sprinter
# 3               DDRS  Dordrecht Stadspolders         36795  Stoptrein
# 4               EMNZ              Emmen Zuid          8083  Stoptrein
# ...              ...                     ...           ...        ...
# 5458993         DDRS  Dordrecht Stadspolders         36782  Stoptrein
# 5458994          HIL                Hillegom          6395   Sprinter
# 5458995           DT                   Delft          5182   Sprinter
# 5458996           VB                Voorburg          9893   Sprinter
# 5458997          HWD           Heerhugowaard          3078  Intercity
#
#         Train_Company Train_Destination_Planned Train_Destination_Actual  \
# 0                  NS        Amsterdam Centraal      Haarlem Spaarnwoude
# 1              Arriva                 Groningen         Bad Nieuweschans
# 2                  NS          Utrecht Centraal             Duivendrecht
# 3              Arriva                 Gorinchem   Dordrecht Stadspolders
# 4              Arriva                     Emmen               Emmen Zuid
# ...               ...                       ...                      ...
# 5458993        Arriva                 Dordrecht                Dordrecht
# 5458994            NS           Leiden Centraal          Leiden Centraal
# 5458995            NS         Den Haag Centraal        Den Haag Centraal
# 5458996            NS          Utrecht Centraal         Utrecht Centraal
# 5458997            NS                Den Helder               Den Helder
#
#         Train_Departure_Planned Train_Departure_Actual  Train_Delay  \
# 0           2016-01-01 00:10:00    2016-01-01 00:10:00          0.0
# 1           2016-01-01 00:10:00    2016-01-01 00:10:00          0.0
# 2           2016-01-01 00:11:00    2016-01-01 00:11:00          0.0
# 3           2016-01-01 00:11:00    2016-01-01 00:11:00          0.0
# 4           2016-01-01 00:11:00    2016-01-01 00:11:00          0.0
# ...                         ...                    ...          ...
# 5458993     2016-01-31 22:58:00    2016-01-31 22:58:00          0.0
# 5458994     2016-01-31 23:00:00    2016-01-31 23:00:00          0.0
# 5458995     2016-01-31 23:00:00    2016-01-31 23:00:00          0.0
# 5458996     2016-01-31 23:01:00    2016-01-31 23:01:00          0.0
# 5458997     2016-01-31 22:58:00    2016-01-31 23:00:38        158.0
#
#         DepartureDatePlanned DepartureTimePlanned DepartureDateActual  \
# 0                 2016-01-01             00:00:00          2016-01-01
# 1                 2016-01-01             00:00:00          2016-01-01
# 2                 2016-01-01             00:00:00          2016-01-01
# 3                 2016-01-01             00:00:00          2016-01-01
# 4                 2016-01-01             00:00:00          2016-01-01
# ...                      ...                  ...                 ...
# 5458993           2016-01-31             00:00:00          2016-01-31
# 5458994           2016-01-31             00:00:00          2016-01-31
# 5458995           2016-01-31             00:00:00          2016-01-31
# 5458996           2016-01-31             00:00:00          2016-01-31
# 5458997           2016-01-31             00:00:00          2016-01-31
#
#         DepartureTimeActual  MaxNumberOfStops  weekday
# 0                  00:00:00                11        4
# 1                  00:00:00                10        4
# 2                  00:00:00                11        4
# 3                  00:00:00                 8        4
# 4                  00:00:00                11        4
# ...                     ...               ...      ...
# 5458993            00:00:00                12        6
# 5458994            00:00:00                 5        6
# 5458995            00:00:00                20        6
# 5458996            00:00:00                12        6
# 5458997            00:00:00                21        6
#
# [5458998 rows x 16 columns]

# %%
#We get the average per day of the week
AverageDelayDay = January.groupby('weekday')['Train_Delay'].mean().reset_index()
AverageDelayDay
# Out:
#    weekday  Train_Delay
# 0        0    78.878189
# 1        1    79.840338
# 2        2    69.468027
# 3        3    82.547173
# 4        4    77.300705
# 5        5    47.387056
# 6        6    78.816216

# %%
#Then we visualise it with bargraph
plt.figure(figsize=(16,10))
plt.bar(AverageDelayDay['weekday'],AverageDelayDay['Train_Delay'])
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# ## Percent delays

# %%
from datetime import timedelta

delta = 0

# Defying a function, that will calculate the percentage
def percentage(part, whole):
  return 100 * float(part)/float(whole)

# The total train departures (rows) (January)
total = len(January)
# The total delays, where minute is bigger than 0 (January)
delays = len(January[January['Train_Delay'] > delta])

perc = percentage(delays,total)

# Results
print('The count of delays: {}'.format(delays))
print('The total train departures count: {}'.format(total))
print('Percentage of delay for January: {:.6f}'.format(perc))
# Out:
# The count of delays: 2046304
# The total train departures count: 5458998
# Percentage of delay for January: 37.484974

# %% [markdown]
# The percentage is 37%.
#
# We can also show the delays between the different train companies to get a better insight. This can be done using pie plot.

# %%
#First grouping the delays with the different train company
compdelays = January[January['Train_Delay'] > delta].groupby(['Train_Company'])['Train_Delay'].count().reset_index()
# Then adding the percentage of delays for each company
compdelays['Percentage (of total)'] = compdelays['Train_Delay'] / total * 100
# Then adding the percentage of delays between the companies (so the sum of the percentage for each company should be 100%)
compdelays['Percentage (of companies)'] = compdelays['Train_Delay'] / delays * 100
# Sorting by most delays
compdelays = compdelays.sort_values(by="Train_Delay", ascending=False)

# Results
compdelays
# Out:
#    Train_Company  Train_Delay  Percentage (of total)  \
# 6             NS      1707131              31.271874
# 0         Arriva       213745               3.915462
# 9         Veolia        82405               1.509526
# 8     Valleilijn        19526               0.357685
# 7         Syntus         9333               0.170965
# 1          Breng         5643               0.103371
# 5           NMBS         4570               0.083715
# 2             DB         3389               0.062081
# 4            LTE          354               0.006485
# 3         Keolis          192               0.003517
# 10          ZLSM           16               0.000293
#
#     Percentage (of companies)
# 6                   83.425092
# 0                   10.445418
# 9                    4.027017
# 8                    0.954208
# 7                    0.456091
# 1                    0.275765
# 5                    0.223329
# 2                    0.165616
# 4                    0.017299
# 3                    0.009383
# 10                   0.000782

# %%
# Showing the amount of delayed departures for each train company
plt.figure(figsize=(16,10))
plt.bar(compdelays['Train_Company'],compdelays['Train_Delay'])
# Out:
# <BarContainer object of 11 artists>

# %% [markdown]
# Here we see the delay percentage of the total train departures and the percentage between the other train companies.

# %%
# Function, that returns a formated number - 5.23423 becomes 5.2
def func(pct):
  return "{:1.1f}%".format(pct)

# Plotting the delay percentage between companies using pie
plt.figure(figsize=(25,25))
plt.pie(compdelays['Train_Delay'], labels=compdelays['Train_Company'], autopct=lambda pct: func(pct), shadow=True)
plt.title('Delays between companies')
plt.show()

# %% [markdown]
# From the plot we see that NS have the most delays compared to the other companies.
#
# In addition, we can plot the stations where delay occurs (may be useful). We are getting only the top 12 stations, sorted from least to most delays in the bar plot.

# %%
print("Number of stations: {}".format(len(January[January['Train_Delay'] > delta]['Station_Name'].unique())))

# Getting delays for each station that the train departured
compdelays = January[January['Train_Delay'] > delta].groupby(['Station_Name'])['Train_Delay'].count().reset_index().sort_values(by=['Train_Delay'])[-12:]
 
# And plotting the results using bar plot
plt.figure(figsize=(26,12))
plt.bar(compdelays['Station_Name'],compdelays['Train_Delay'])
plt.title('Delays between stations')
plt.show()
# Out:
# Number of stations: 401

# %% [markdown]
# We observe that Schiphol Airport, Amsterdam Sloterdijk, Amsterdam Zuid and Rotterdam Centrall have the most delays for January.
# ## Amount of delays

# %%
#Add a column for the day of the week
January['day_of_week'] = January['DepartureDatePlanned'].dt.day_name()

# %%
from datetime import timedelta

#For now, we will call it a delay when there is a minimum delay of 2 minutes
#Example: 5 seconds delay, will not be called a delay, but 2 minutes will
delta = 2

#Calculate how many delays each date will have
amountDelays = January[January['Train_Delay'] >= delta].groupby(['DepartureDatePlanned'])['Train_Delay'].count().reset_index()
amountDelays = amountDelays.sort_values(by="DepartureDatePlanned", ascending=True)

#Add the day of the week
amountDelays['day_of_week'] = amountDelays['DepartureDatePlanned'].dt.day_name()

amountDelays
# Out:
#    DepartureDatePlanned  Train_Delay day_of_week
# 0            2015-12-31            7    Thursday
# 1            2016-01-01        38772      Friday
# 2            2016-01-02        44130    Saturday
# 3            2016-01-03        43071      Sunday
# 4            2016-01-04        78256      Monday
# 5            2016-01-05        75926     Tuesday
# 6            2016-01-06        67611   Wednesday
# 7            2016-01-07        77137    Thursday
# 8            2016-01-08        78831      Friday
# 9            2016-01-09        49463    Saturday
# 10           2016-01-10        41163      Sunday
# 11           2016-01-11        72616      Monday
# 12           2016-01-12        77122     Tuesday
# 13           2016-01-13        72369   Wednesday
# 14           2016-01-14        88209    Thursday
# 15           2016-01-15        83350      Friday
# 16           2016-01-16        46943    Saturday
# 17           2016-01-17        45875      Sunday
# 18           2016-01-18        87470      Monday
# 19           2016-01-19        84535     Tuesday
# 20           2016-01-20        77194   Wednesday
# 21           2016-01-21        90932    Thursday
# 22           2016-01-22        83187      Friday
# 23           2016-01-23        47593    Saturday
# 24           2016-01-24        41882      Sunday
# 25           2016-01-25        66270      Monday
# 26           2016-01-26        75903     Tuesday
# 27           2016-01-27        73353   Wednesday
# 28           2016-01-28        65466    Thursday
# 29           2016-01-29        77222      Friday
# 30           2016-01-30        47310    Saturday
# 31           2016-01-31        44528      Sunday
# 32           2016-02-01            1      Monday

# %%
plt.figure(figsize=(16,10))
plt.bar(amountDelays['DepartureDatePlanned'],amountDelays['Train_Delay'])
# Out:
# <BarContainer object of 33 artists>

# %% [markdown]
# Here we see how many delays each date has, where the weekends have the least amount of delays but this doesn't show anything about how long the delays took

# %%
amountDelaysPerDay = January[January['Train_Delay'] > delta].groupby(['day_of_week'])['Train_Delay'].mean().reset_index().sort_values(by=['Train_Delay'])
print(amountDelaysPerDay)

plt.figure(figsize=(16,10))
plt.bar(amountDelaysPerDay['day_of_week'],amountDelaysPerDay['Train_Delay'])
plt.title('Delays mean')
plt.show()
# Out:
#   day_of_week  Train_Delay
# 6   Wednesday   182.534383
# 3      Sunday   184.518525
# 5     Tuesday   195.596199
# 0      Friday   197.015107
# 4    Thursday   203.566121
# 1      Monday   204.455559
# 2    Saturday   207.482117

# %% [markdown]
# We can see the average delay for each weekday in Jarnuary. The average delay on Saturday is higher than the rest of the days.

# %% [markdown]
# ## Correlation investigation

# %% [markdown]
# In this code I use a library called isodate specifically to parse iso format datetimes as is present in the raw data.
# I load the data again because I needed to change the column names to names without white spaces, in order to use a specific in-line method later.
#
# Below here I load the date and rename the columns.

# %%
import isodate
df = pd.read_csv('January.csv')
df = df.drop(columns = 'Unnamed: 0')
df = df.rename(columns={"Station Code": "Station_Code", "Station Name": "Station_Name", "Train Number": "Train_Number", "Train Type": "Train_Type", "Train Company": "Train_Company", "Train Destination Planned": "Train_Destination_Planned", "Train Destination Actual": "Train_Destination_Actual", "Train Departure Planned": "Train_Departure_Planned", "Train Departure Actual": "Train_Departure_Actual", "Train Delay": "Train_Delay"})

# %% [markdown]
# Below I investigated how many train identification numbers exist in the month of January

# %%
pd.unique(df.Train_Number).shape
# Out:
# (8046,)

# %% [markdown]
# 8046 unique train numbers exist only in January, I can't possibly try correlation on this. It would also likely not yield anything.
# However as you can see below some train numbers (presumably the id of the physical train) are used much more often than others. 3894 vs 1 for some trains. We could use this

# %%
pd.value_counts(df.Train_Number)
# Out:
# 12685     3894
# 12683     3727
# 4082      3623
# 5756      3566
# 5765      3564
#           ...
# 309671       1
# 301685       1
# 303520       1
# 300769       1
# 300567       1
# Name: Train_Number, Length: 8046, dtype: int64

# %%
#Below here I try to visualize the unique train numbers with more rows but it seems not to work
with pd.option_context('display.max_rows', 100, 'display.max_columns', None):  # more options can be specified also
    print(pd.value_counts(df.Train_Number))

#Below I define a dataset by all journeys made by a specific train (the one with the most data in January)
dfBigTrain = df.loc[df['Train_Number'] == 12683]
dfBigTrain

#Finaly I use the isodate library to parse the iso format delay into a regular timedelta 
#I can use this timedelta later to convert to a delay measured in seconds
df['Train_Delay_Seconds'] = df.apply(lambda row: isodate.parse_duration(row.Train_Delay), axis=1)
df
df.dtypes
# Out:
# 12685     3894
# 12683     3727
# 4082      3623
# 5756      3566
# 5765      3564
#           ...
# 309671       1
# 301685       1
# 303520       1
# 300769       1
# 300567       1
# Name: Train_Number, Length: 8046, dtype: int64
# Station_Code                          object
# Station_Name                          object
# Train_Number                           int64
# Train_Type                            object
# Train_Company                         object
# Train_Destination_Planned             object
# Train_Destination_Actual              object
# Train_Departure_Planned               object
# Train_Departure_Actual                object
# Train_Delay                           object
# Train_Delay_Seconds          timedelta64[ns]
# dtype: object

# %% [markdown]
# Here I convert the timedelta delay into seconds

# %%
df['Train_Delay_Seconds'] = df.apply(lambda row: row.Train_Delay_Seconds.total_seconds(), axis=1)
df
#Here I check how many train types exist, this is the most promising feature for correlation
pd.unique(df['Train_Type'])
# Out:
# array(['Sprinter', 'Stoptrein', 'Intercity', 'Intercity direct',
#        'Sneltrein', 'Thalys', 'CityNightLine/IC', 'Speciale Trein',
#        'ICE International', 'Austria Express', 'Stoomtrein',
#        'Extra trein', 'Panorama Rail'], dtype=object)

# %% [markdown]
# As you can see above they don't seem like a lot of types so I can probably generate dummies without issue
# Let's do that below and add the dummies to the dataset.

# %%
pd.get_dummies(df.Train_Type)
#Here I create the dummies from the train types and then add them to the original dataset
df = pd.concat([df, pd.get_dummies(df.Train_Type)], axis=1);
df
#You can see below the dummies are uint8 types that are either 0 or 1
df.dtypes
# Out:
# Station_Code                  object
# Station_Name                  object
# Train_Number                   int64
# Train_Type                    object
# Train_Company                 object
# Train_Destination_Planned     object
# Train_Destination_Actual      object
# Train_Departure_Planned       object
# Train_Departure_Actual        object
# Train_Delay                   object
# Train_Delay_Seconds          float64
# Austria Express                uint8
# CityNightLine/IC               uint8
# Extra trein                    uint8
# ICE International              uint8
# Intercity                      uint8
# Intercity direct               uint8
# Panorama Rail                  uint8
# Sneltrein                      uint8
# Speciale Trein                 uint8
# Sprinter                       uint8
# Stoomtrein                     uint8
# Stoptrein                      uint8
# Thalys                         uint8
# dtype: object

# %%
#Below I check how many unique stations exist. This might inform me if can make dummies out of those
pd.unique(df.Station_Name).shape
#But of course There are far too many unique stations to do correlation with them
# Out:
# (403,)

# %%
#Below I visualize the correlation matrix and you can see that 'Austria express' and 'LTE' as Train types have the highest correlation at 0.52
sns.set(rc={'figure.figsize':(18,11)})
sns.heatmap(df.corr().round(decimals=2), annot=True, cbar=None, vmax=2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# As you can see above from the correlation matrix the highest correlation with delay duration is a type of train called 'Austria Express'
# Let's find out how often a train is of that type below.

# %%
pd.value_counts(df.Train_Type)
# Out:
# Sprinter             2852909
# Intercity            1413521
# Stoptrein            1081923
# Sneltrein              54984
# Intercity direct       36870
# Thalys                  9855
# ICE International       3748
# Extra trein             2010
# Speciale Trein          1436
# CityNightLine/IC        1162
# Austria Express          472
# Stoomtrein               106
# Panorama Rail              2
# Name: Train_Type, dtype: int64

# %% [markdown]
# It seems Austria Express as a Train Type is only present in 472 rows in the whole month of January compared to different types of NS trains which are present as often as 2852909.

# %%
#Here I create a dataset only with those 472 rows from Austria Express trains
dfAustriaExpress = df.loc[df['Train_Type'] == 'Austria Express']
#Then I show how often certain delay durations occur
print(pd.value_counts(dfAustriaExpress.Train_Delay_Seconds).to_string())
#Looking below you can 118 of 472 austria express departures have 0 delays.
#16 have 86400 seconds (24 hours) of delay!

#Below I check the same for LTE
dfLTE = df.loc[df['Train_Company'] == 'LTE']
print(pd.value_counts(dfLTE.Train_Delay_Seconds).to_string())
dfAustriaExpress.dtypes
#It seems a lot of these journeys are above 80,000 seconds delayed (which is often enough to be 1 day late or more). 
#This is probably not very represantative so we need to investigate if we can leave these outliers out.


#From the name Austria Express probably goes to Austria and is an international train
#We can probably leave it out as it's not useful for making predictions in the Netherlands
#But just to be sure, below I check which destinations Austria Express trains end in.
print(pd.unique(dfAustriaExpress.Train_Destination_Planned))
# Out:
# 0.0        118
# 86400.0     16
# 7200.0       8
# 6945.0       6
# 420.0        6
# 6789.0       5
# 362.0        4
# 7560.0       4
# 86908.0      4
# 87460.0      4
# 120.0        3
# 478.0        3
# 89993.0      3
# 87324.0      3
# 90448.0      3
# 87210.0      3
# 240.0        3
# 63.0         3
# 129.0        3
# 86736.0      3
# 87805.0      3
# 954.0        2
# 6715.0       1
# 6800.0       1
# 6693.0       1
# 180.0        1
# 89780.0      1
# 7326.0       1
# 3600.0       1
# 6361.0       1
# 87310.0      1
# 4500.0       1
# 3367.0       1
# 4194.0       1
# 5400.0       1
# 5094.0       1
# 4267.0       1
# 4020.0       1
# 5694.0       1
# 4620.0       1
# 88769.0      1
# 6000.0       1
# 89288.0      1
# 5767.0       1
# 6594.0       1
# 5520.0       1
# 4634.0       1
# 4387.0       1
# 6953.0       1
# 89437.0      1
# 87592.0      1
# 87380.0      1
# 7440.0       1
# 397.0        1
# 6968.0       1
# 6336.0       1
# 7163.0       1
# 6254.0       1
# 7081.0       1
# 6163.0       1
# 6102.0       1
# 6929.0       1
# 6039.0       1
# 6866.0       1
# 6118.0       1
# 6590.0       1
# 6654.0       1
# 6562.0       1
# 6483.0       1
# 6648.0       1
# 6752.0       1
# 6824.0       1
# 6848.0       1
# 5228.0       1
# 89344.0      1
# 5820.0       1
# 306.0        1
# 369.0        1
# 294.0        1
# 149.0        1
# 320.0        1
# 763.0        1
# 1069.0       1
# 2094.0       1
# 492.0        1
# 1267.0       1
# 3148.0       1
# 2842.0       1
# 2015.0       1
# 225.0        1
# 6174.0       1
# 6480.0       1
# 5347.0       1
# 6894.0       1
# 6067.0       1
# 6743.0       1
# 7052.0       1
# 87096.0      1
# 89962.0      1
# 87004.0      1
# 86485.0      1
# 89526.0      1
# 86691.0      1
# 87275.0      1
# 86756.0      1
# 86472.0      1
# 86941.0      1
# 90045.0      1
# 86657.0      1
# 87122.0      1
# 86838.0      1
# 87199.0      1
# 87297.0      1
# 87013.0      1
# 87454.0      1
# 87170.0      1
# 87308.0      1
# 558.0        1
# 89443.0      1
# 90065.0      1
# 7085.0       1
# 86773.0      1
# 7023.0       1
# 7179.0       1
# 89412.0      1
# 7800.0       1
# 89497.0      1
# 89566.0      1
# 86551.0      1
# 89474.0      1
# 86968.0      1
# 86476.0      1
# 87033.0      1
# 86541.0      1
# 87111.0      1
# 86619.0      1
# 89546.0      1
# 86723.0      1
# 86652.0      1
# 87144.0      1
# 87265.0      1
# 87215.0      1
# ['Landeck' 'Brussel-Zuid/Midi']

# %% [markdown]
# Above at the end you can see the destinations are not relevant for use so below I remove Austria express and check correlation again.

# %%
df = df[df['Train_Type'] != 'Austria Express']
df
df = df.drop(columns = 'Austria Express')
sns.set(rc={'figure.figsize':(18,11)})
sns.heatmap(df.corr().round(decimals=2), annot=True, cbar=None, vmax=2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# After removing Austria Express it seems all dummies correlate negatively with delay duration

# %%
pd.value_counts(df.Train_Destination_Planned)
# Out:
# Den Haag Centraal     429778
# Utrecht Centraal      336237
# Amsterdam Centraal    293633
# Zwolle                287166
# Nijmegen              264959
#                        ...
# Maarn                      5
# Heerenveen                 4
# Delft                      2
# Boxtel                     2
# Almere Centrum             1
# Name: Train_Destination_Planned, Length: 135, dtype: int64

# %% [markdown]
# Moving on I check which destinations are most used as train destinations.
# I want to investigate if we can track a trains complete journey and investigate delays when accounting for previous station delays.

# %%
dfDenHaag = df.loc[df['Train_Destination_Planned'] == 'Den Haag Centraal']
dfDenHaag
pd.unique(dfDenHaag.Station_Name).shape
# Out:
# (97,)

# %% [markdown]
# Above as you can out of all 429778 train departures with end destination 'Den Haag Centraal', 97 depart from different stations.

# %% [markdown]
# ## Correlation with stations?
# Below I load the dataset again without dummies. Convert the delay to seconds and rename the columns again...
#
# I filter the dataset by trains with end destination as Nijmegen and check how many stations they depart from.

# %%
df1 = pd.read_csv("January.csv")
df1
df1 = df1.drop(columns = 'Unnamed: 0')
df1 = df1.rename(columns={"Station Code": "Station_Code", "Station Name": "Station_Name", "Train Number": "Train_Number", "Train Type": "Train_Type", "Train Company": "Train_Company", "Train Destination Planned": "Train_Destination_Planned", "Train Destination Actual": "Train_Destination_Actual", "Train Departure Planned": "Train_Departure_Planned", "Train Departure Actual": "Train_Departure_Actual", "Train Delay": "Train_Delay"})
df1['Train_Delay_Seconds'] = df1.apply(lambda row: isodate.parse_duration(row.Train_Delay).total_seconds(), axis=1)
dfNijmegen = df1.loc[df1['Train_Destination_Planned'] == 'Nijmegen']
dfNijmegen
pd.value_counts(dfNijmegen['Train_Delay_Seconds'])
pd.unique(dfNijmegen.Station_Name).shape
# Out:
# (71,)

# %% [markdown]
# I decide 71 is a lot of stations but still decide to try.
# I create dummies for each of the stations and investigate correlation

# %%
dfNijmegen = pd.concat([dfNijmegen, pd.get_dummies(dfNijmegen.Station_Name)], axis=1);
dfNijmegen
sns.set(rc={'figure.figsize':(18,11)})
sns.heatmap(dfNijmegen.corr().round(decimals=0), annot=True, cbar=None, vmax=2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Above you can see a "correlation matrix" of every unique departure station with delay duration. It includes 71 columns and none correlate. So we should probably forget about taking the specific station the train is departing from into account for calculating delays

# %% [markdown]
# ## NaNs per month

# %% [markdown]
# In this step we can go through each month and see how many nan values are there. For that, first we need to create an array that will hold every month.

# %%
months = [January,February,March,April,May,June, July, August, September, October, November, December]

# %% [markdown]
# Then we can create a array that will hold all the nan values. In a for loop we can go through each month and add every feature that have NaN values to the array.

# %%
total_nans = []

# loop that goes through the months of 2016
for i, month in enumerate(months):
    m = i + 1 # the number of the month, + ` because index starts with 0
    nans = month.isna().sum()[month.isna().sum() > 0]
    
    total_nans.append(nans)
    # Showing the features with the amount of nans for each month
    print("For month {}: \n  {}".format(m,nans))
# Out:
# For month 1:
#   Station_Code    8519
# dtype: int64
# For month 2:
#   Station Code    7789
# dtype: int64
# For month 3:
#   Station Code    8544
# dtype: int64
# For month 4:
#   Station Code    3347
# dtype: int64
# For month 5:
#   Station Code    9096
# dtype: int64
# For month 6:
#   Station Code    8255
# dtype: int64
# For month 7:
#   Station Code    9424
# dtype: int64
# For month 8:
#   Station Code    8932
# dtype: int64
# For month 9:
#   Station Code    8705
# dtype: int64
# For month 10:
#   Station Code    8931
# dtype: int64
# For month 11:
#   Station Code    9811
# dtype: int64
# For month 12:
#   Station Code    1917
# dtype: int64

# %% [markdown]
# Then we create a dataframe of the array with nans, so it is easier to visualize the data. In addition we are creating a months column that will hold the names of the months, instead of just a number. This is done using map().

# %%
# Creating a dataframe with all the NaN values
nulls = pd.DataFrame(total_nans).reset_index()

nulls['months'] = nulls['index'].map({0:'January',1:'February',2:'March',3:'April',4:'May',5:'June',6:'July',7:'August',8:'September',9:'October',10:'November',11:'December'})

# And to see the dataframe
nulls
# Out:
#     index  Station_Code  Station Code     months
# 0       0        8519.0           NaN    January
# 1       1           NaN        7789.0   February
# 2       2           NaN        8544.0      March
# 3       3           NaN        3347.0      April
# 4       4           NaN        9096.0        May
# 5       5           NaN        8255.0       June
# 6       6           NaN        9424.0       July
# 7       7           NaN        8932.0     August
# 8       8           NaN        8705.0  September
# 9       9           NaN        8931.0    October
# 10     10           NaN        9811.0   November
# 11     11           NaN        1917.0   December

# %% [markdown]
# Now we can plot the nans for each month using the month column as x and the features with missing data as y. In our case it is only station code. For january, the column is called Station_Code and for the rest is Station Code and that is the reason for the bar plot to have 2 bars per month.

# %%
# Using x as the month and y as the features, that contain NaN, we can plot our dataframe
nulls.plot(x='index',
          y=['Station_Code','Station Code'],
          kind="bar", figsize=(15,10), title="Missing data for each month", fontsize=16)

plt.xlabel('Months', fontsize=18)
plt.ylabel('Missing data', fontsize=18)
# Out:
# Text(0, 0.5, 'Missing data')

# %% [markdown]
# But to have it in more readable dataframe, we can fix the column names and keep only the month names + nans.

# %%
# We are setting Station Code to be Station_Code for January
nulls.loc[nulls['months'] == 'January',"Station Code"] = nulls.loc[nulls['months'] == 'January',"Station_Code"]

# Dropping the unused columns
nulls = nulls.drop('Station_Code', axis=1)
nulls = nulls.drop('index', axis=1)

# %% [markdown]
# And we can see the nan values for each month from the month with the most nans to the month with least.

# %%
# Sorting from bigger amount of NaN to less
nulls.sort_values(by='Station Code', ascending=False)
# Out:
#     Station Code     months
# 10        9811.0   November
# 6         9424.0       July
# 4         9096.0        May
# 7         8932.0     August
# 9         8931.0    October
# 8         8705.0  September
# 2         8544.0      March
# 0         8519.0    January
# 5         8255.0       June
# 1         7789.0   February
# 3         3347.0      April
# 11        1917.0   December

# %%
dfSchiphol = January.loc[January['Train_Destination_Planned'] == "Schiphol Airport"]

# %%
pd.unique(dfSchiphol.Train_Type)
# Out:
# array(['Intercity', 'Sprinter', 'Extra trein'], dtype=object)

# %%
pd.unique(dfSchiphol.Train_Company)
# Out:
# array(['NS'], dtype=object)

# %% [markdown]
# # Conclusion
# Taking into account everyone's insights and conclusions as well as Ordina's advice from our previous proposal meeting we decided to start modeling on a small dataset. Because all of the missing values are station codes which are a shortened version of the station name we can simply ignore the station codes to remove the missing values.
#
# We decided to focus on a filtered dataset of the month of January with only a popular train destination as an end Destination (Schiphol Airport). Filtering it by Schiphol Airport as end destination in January we see above that the only train types are Intercitys, Sprintters and extra trein and the only train company is NS. This means using this dataset will be appropriate and manageable as we keep it small and filtered. It will also eliminate all companies and destinations that are not relevant here as a side benefit.
#
# Below we save a this as a csv to use in the modeling notebook

# %%
dfSchiphol.to_csv('January_Schiphol_Cleaned.csv')
