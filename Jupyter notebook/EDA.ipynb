# %%
#here i load the libraries
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import display
import seaborn as sns
import datetime
sns.set_theme()

# %%
January=pd.read_csv('January.csv')
January.drop('Unnamed: 0',axis=1,inplace=True)
January.info()
January
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5458998 entries, 0 to 5458997
# Data columns (total 8 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Station Code             object
#  1   Station Name             object
#  2   Train Number             int64
#  3   Train Type               object
#  4   Train Company            object
#  5   Train Destination        object
#  6   Train Planned Departure  object
#  7   Train Delay              object
# dtypes: int64(1), object(7)
# memory usage: 333.2+ MB
#         Station Code            Station Name  Train Number Train Type  \
# 0               HLMS     Haarlem Spaarnwoude         14882   Sprinter
# 1               NSCH        Bad Nieuweschans         37598  Stoptrein
# 2                DVD            Duivendrecht          7495   Sprinter
# 3               DDRS  Dordrecht Stadspolders         36795  Stoptrein
# 4               EMNZ              Emmen Zuid          8083  Stoptrein
# ...

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date
January['Train Planned Departure']=pd.to_datetime(January['Train Planned Departure'], format="%Y-%m-%dT%H:%M:%SZ")
January['Train Planned Departure1']=January['Train Planned Departure'].astype(str)
January[['DepartureDate','DepartureTime']]= January['Train Planned Departure1'].str.split(' ', expand = True)
January['DepartureDate']=pd.to_datetime(January['DepartureDate'])
January
# Out:
#         Station Code            Station Name  Train Number Train Type  \
# 0               HLMS     Haarlem Spaarnwoude         14882   Sprinter
# 1               NSCH        Bad Nieuweschans         37598  Stoptrein
# 2                DVD            Duivendrecht          7495   Sprinter
# 3               DDRS  Dordrecht Stadspolders         36795  Stoptrein
# 4               EMNZ              Emmen Zuid          8083  Stoptrein
# ...              ...                     ...           ...        ...
# 5458993         DDRS  Dordrecht Stadspolders         36782  Stoptrein
# 5458994          HIL                Hillegom          6395   Sprinter
# 5458995           DT                   Delft          5182   Sprinter
# 5458996           VB                Voorburg          9893   Sprinter
# 5458997          HWD           Heerhugowaard          3078  Intercity
#
#         Train Company       Train Destination Train Planned Departure  \
# ...

# %%
#then i make the depature time a time delta (Actually want to make it a normal time format)
January['DepartureTime']=pd.to_timedelta(January['DepartureTime'].str.strip())
print(January.info())
January
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5458998 entries, 0 to 5458997
# Data columns (total 11 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Station Code              object
#  1   Station Name              object
#  2   Train Number              int64
#  3   Train Type                object
#  4   Train Company             object
#  5   Train Destination         object
#  6   Train Planned Departure   datetime64[ns]
#  7   Train Delay               object
#  8   Train Planned Departure1  object
#  9   DepartureDate             datetime64[ns]
#  10  DepartureTime             timedelta64[ns]
# dtypes: datetime64[ns](2), int64(1), object(7), timedelta64[ns](1)
# memory usage: 458.1+ MB
# None
#         Station Code            Station Name  Train Number Train Type  \
# 0               HLMS     Haarlem Spaarnwoude         14882   Sprinter
# 1               NSCH        Bad Nieuweschans         37598  Stoptrein
# ...

# %%
#Then i also put the delay in time delta format
January['Train Delay']=pd.to_timedelta(January['Train Delay'].str.strip())
January
# Out:
#         Station Code            Station Name  Train Number Train Type  \
# 0               HLMS     Haarlem Spaarnwoude         14882   Sprinter
# 1               NSCH        Bad Nieuweschans         37598  Stoptrein
# 2                DVD            Duivendrecht          7495   Sprinter
# 3               DDRS  Dordrecht Stadspolders         36795  Stoptrein
# 4               EMNZ              Emmen Zuid          8083  Stoptrein
# ...              ...                     ...           ...        ...
# 5458993         DDRS  Dordrecht Stadspolders         36782  Stoptrein
# 5458994          HIL                Hillegom          6395   Sprinter
# 5458995           DT                   Delft          5182   Sprinter
# 5458996           VB                Voorburg          9893   Sprinter
# 5458997          HWD           Heerhugowaard          3078  Intercity
#
#         Train Company       Train Destination Train Planned Departure  \
# ...

# %%
February=pd.read_csv('February.csv')
February.drop('Unnamed: 0',axis=1,inplace=True)
February.info()
February
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5248684 entries, 0 to 5248683
# Data columns (total 8 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Station Code             object
#  1   Station Name             object
#  2   Train Number             int64
#  3   Train Type               object
#  4   Train Company            object
#  5   Train Destination        object
#  6   Train Planned Departure  object
#  7   Train Delay              object
# dtypes: int64(1), object(7)
# memory usage: 320.4+ MB
#         Station Code           Station Name  Train Number Train Type  \
# 0                VDW       Vlaardingen West          4197   Sprinter
# 1               HLMS    Haarlem Spaarnwoude         14882   Sprinter
# 2               NSCH       Bad Nieuweschans         37598  Stoptrein
# 3                HWD          Heerhugowaard          4082   Sprinter
# 4                BGN         Bergen op Zoom          2674  Intercity
# ...

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date
February['Train Planned Departure']=pd.to_datetime(February['Train Planned Departure'], format="%Y-%m-%dT%H:%M:%SZ")
February['Train Planned Departure1']=February['Train Planned Departure'].astype(str)
February[['DepartureDate','DepartureTime']]= February['Train Planned Departure1'].str.split(' ', expand = True)
February['DepartureDate']=pd.to_datetime(February['DepartureDate'])
February
#then i make the depature time a time delta (Actually want to make it a normal time format)
February['DepartureTime']=pd.to_timedelta(February['DepartureTime'].str.strip())
print(February.info())
February
#Then i also put the delay in time delta format
February['Train Delay']=pd.to_timedelta(February['Train Delay'].str.strip())
February
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5248684 entries, 0 to 5248683
# Data columns (total 11 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Station Code              object
#  1   Station Name              object
#  2   Train Number              int64
#  3   Train Type                object
#  4   Train Company             object
#  5   Train Destination         object
#  6   Train Planned Departure   datetime64[ns]
#  7   Train Delay               object
#  8   Train Planned Departure1  object
#  9   DepartureDate             datetime64[ns]
#  10  DepartureTime             timedelta64[ns]
# dtypes: datetime64[ns](2), int64(1), object(7), timedelta64[ns](1)
# memory usage: 440.5+ MB
# None
#         Station Code           Station Name  Train Number Train Type  \
# 0                VDW       Vlaardingen West          4197   Sprinter
# 1               HLMS    Haarlem Spaarnwoude         14882   Sprinter
# ...

# %%
March=pd.read_csv('March.csv')
March.drop('Unnamed: 0',axis=1,inplace=True)
March.info()
March
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5433078 entries, 0 to 5433077
# Data columns (total 8 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Station Code             object
#  1   Station Name             object
#  2   Train Number             int64
#  3   Train Type               object
#  4   Train Company            object
#  5   Train Destination        object
#  6   Train Planned Departure  object
#  7   Train Delay              object
# dtypes: int64(1), object(7)
# memory usage: 331.6+ MB
#         Station Code            Station Name  Train Number Train Type  \
# 0               LEDN         Leiden Centraal          2691  Intercity
# 1               HLMS     Haarlem Spaarnwoude         14882   Sprinter
# 2               NSCH        Bad Nieuweschans         37598  Stoptrein
# 3                 CL               Culemborg         16084   Sprinter
# 4                CAS               Castricum         14889   Sprinter
# ...

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date
March['Train Planned Departure']=pd.to_datetime(March['Train Planned Departure'], format="%Y-%m-%dT%H:%M:%SZ")
March['Train Planned Departure1']=March['Train Planned Departure'].astype(str)
March[['DepartureDate','DepartureTime']]= March['Train Planned Departure1'].str.split(' ', expand = True)
March['DepartureDate']=pd.to_datetime(March['DepartureDate'])
March
#then i make the depature time a time delta (Actually want to make it a normal time format)
March['DepartureTime']=pd.to_timedelta(March['DepartureTime'].str.strip())
print(March.info())
March
#Then i also put the delay in time delta format
March['Train Delay']=pd.to_timedelta(March['Train Delay'].str.strip())
March
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5433078 entries, 0 to 5433077
# Data columns (total 11 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Station Code              object
#  1   Station Name              object
#  2   Train Number              int64
#  3   Train Type                object
#  4   Train Company             object
#  5   Train Destination         object
#  6   Train Planned Departure   datetime64[ns]
#  7   Train Delay               object
#  8   Train Planned Departure1  object
#  9   DepartureDate             datetime64[ns]
#  10  DepartureTime             timedelta64[ns]
# dtypes: datetime64[ns](2), int64(1), object(7), timedelta64[ns](1)
# memory usage: 456.0+ MB
# None
#         Station Code            Station Name  Train Number Train Type  \
# 0               LEDN         Leiden Centraal          2691  Intercity
# 1               HLMS     Haarlem Spaarnwoude         14882   Sprinter
# ...

# %%
April=pd.read_csv('April.csv')
April.drop('Unnamed: 0',axis=1,inplace=True)
April.info()
April
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5511575 entries, 0 to 5511574
# Data columns (total 8 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Station Code             object
#  1   Station Name             object
#  2   Train Number             int64
#  3   Train Type               object
#  4   Train Company            object
#  5   Train Destination        object
#  6   Train Planned Departure  object
#  7   Train Delay              object
# dtypes: int64(1), object(7)
# memory usage: 336.4+ MB
#         Station Code          Station Name  Train Number Train Type  \
# 0                UTO     Utrecht Overvecht          5786   Sprinter
# 1                HOR    Hollandsche Rading          5786   Sprinter
# 2               HVSP   Hilversum Sportpark          5786   Sprinter
# 3                HVS             Hilversum          5786   Sprinter
# 4                NDB        Naarden-Bussum          5786   Sprinter
# ...

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date
April['Train Planned Departure']=pd.to_datetime(April['Train Planned Departure'], format="%Y-%m-%dT%H:%M:%SZ")
April['Train Planned Departure1']=April['Train Planned Departure'].astype(str)
April[['DepartureDate','DepartureTime']]= April['Train Planned Departure1'].str.split(' ', expand = True)
April['DepartureDate']=pd.to_datetime(April['DepartureDate'])
April
#then i make the depature time a time delta (Actually want to make it a normal time format)
April['DepartureTime']=pd.to_timedelta(April['DepartureTime'].str.strip())
print(April.info())
April
#Then i also put the delay in time delta format
April['Train Delay']=pd.to_timedelta(April['Train Delay'].str.strip())
April
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5511575 entries, 0 to 5511574
# Data columns (total 11 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Station Code              object
#  1   Station Name              object
#  2   Train Number              int64
#  3   Train Type                object
#  4   Train Company             object
#  5   Train Destination         object
#  6   Train Planned Departure   datetime64[ns]
#  7   Train Delay               object
#  8   Train Planned Departure1  object
#  9   DepartureDate             datetime64[ns]
#  10  DepartureTime             timedelta64[ns]
# dtypes: datetime64[ns](2), int64(1), object(7), timedelta64[ns](1)
# memory usage: 462.5+ MB
# None
#         Station Code          Station Name  Train Number Train Type  \
# 0                UTO     Utrecht Overvecht          5786   Sprinter
# 1                HOR    Hollandsche Rading          5786   Sprinter
# ...

# %%
May=pd.read_csv('May.csv')
May.drop('Unnamed: 0',axis=1,inplace=True)
May.info()
May
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5718506 entries, 0 to 5718505
# Data columns (total 8 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Station Code             object
#  1   Station Name             object
#  2   Train Number             int64
#  3   Train Type               object
#  4   Train Company            object
#  5   Train Destination        object
#  6   Train Planned Departure  object
#  7   Train Delay              object
# dtypes: int64(1), object(7)
# memory usage: 349.0+ MB
#         Station Code          Station Name  Train Number Train Type  \
# 0                 WZ                 Wezep          5688   Sprinter
# 1                UTO     Utrecht Overvecht          5786   Sprinter
# 2                 WH                 Wijhe          3680  Intercity
# 3                UTO     Utrecht Overvecht          5786   Sprinter
# 4               GERP  Groningen Europapark          9196   Sprinter
# ...

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date
May['Train Planned Departure']=pd.to_datetime(May['Train Planned Departure'], format="%Y-%m-%dT%H:%M:%SZ")
May['Train Planned Departure1']=May['Train Planned Departure'].astype(str)
May[['DepartureDate','DepartureTime']]= May['Train Planned Departure1'].str.split(' ', expand = True)
May['DepartureDate']=pd.to_datetime(May['DepartureDate'])
May
#then i make the depature time a time delta (Actually want to make it a normal time format)
May['DepartureTime']=pd.to_timedelta(May['DepartureTime'].str.strip())
print(May.info())
May
#Then i also put the delay in time delta format
May['Train Delay']=pd.to_timedelta(May['Train Delay'].str.strip())
May
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5718506 entries, 0 to 5718505
# Data columns (total 11 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Station Code              object
#  1   Station Name              object
#  2   Train Number              int64
#  3   Train Type                object
#  4   Train Company             object
#  5   Train Destination         object
#  6   Train Planned Departure   datetime64[ns]
#  7   Train Delay               object
#  8   Train Planned Departure1  object
#  9   DepartureDate             datetime64[ns]
#  10  DepartureTime             timedelta64[ns]
# dtypes: datetime64[ns](2), int64(1), object(7), timedelta64[ns](1)
# memory usage: 479.9+ MB
# None
#         Station Code          Station Name  Train Number Train Type  \
# 0                 WZ                 Wezep          5688   Sprinter
# 1                UTO     Utrecht Overvecht          5786   Sprinter
# ...

# %%
June=pd.read_csv('June.csv')
June.drop('Unnamed: 0',axis=1,inplace=True)
June.info()
June
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5743211 entries, 0 to 5743210
# Data columns (total 8 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Station Code             object
#  1   Station Name             object
#  2   Train Number             int64
#  3   Train Type               object
#  4   Train Company            object
#  5   Train Destination        object
#  6   Train Planned Departure  object
#  7   Train Delay              object
# dtypes: int64(1), object(7)
# memory usage: 350.5+ MB
#         Station Code         Station Name  Train Number Train Type  \
# 0                UTO    Utrecht Overvecht          5786   Sprinter
# 1               HLMS  Haarlem Spaarnwoude         14882   Sprinter
# 2                VDW     Vlaardingen West          4197   Sprinter
# 3               NSCH     Bad Nieuweschans         37598  Stoptrein
# 4                 BD                Breda          1987  Intercity
# ...

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date
June['Train Planned Departure']=pd.to_datetime(June['Train Planned Departure'], format="%Y-%m-%dT%H:%M:%SZ")
June['Train Planned Departure1']=June['Train Planned Departure'].astype(str)
June[['DepartureDate','DepartureTime']]= June['Train Planned Departure1'].str.split(' ', expand = True)
June['DepartureDate']=pd.to_datetime(June['DepartureDate'])
June
#then i make the depature time a time delta (Actually want to make it a normal time format)
June['DepartureTime']=pd.to_timedelta(June['DepartureTime'].str.strip())
print(June.info())
June
#Then i also put the delay in time delta format
June['Train Delay']=pd.to_timedelta(June['Train Delay'].str.strip())
June
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5743211 entries, 0 to 5743210
# Data columns (total 11 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Station Code              object
#  1   Station Name              object
#  2   Train Number              int64
#  3   Train Type                object
#  4   Train Company             object
#  5   Train Destination         object
#  6   Train Planned Departure   datetime64[ns]
#  7   Train Delay               object
#  8   Train Planned Departure1  object
#  9   DepartureDate             datetime64[ns]
#  10  DepartureTime             timedelta64[ns]
# dtypes: datetime64[ns](2), int64(1), object(7), timedelta64[ns](1)
# memory usage: 482.0+ MB
# None
#         Station Code         Station Name  Train Number Train Type  \
# 0                UTO    Utrecht Overvecht          5786   Sprinter
# 1               HLMS  Haarlem Spaarnwoude         14882   Sprinter
# ...

# %%
July=pd.read_csv('July.csv')
July.drop('Unnamed: 0',axis=1,inplace=True)
July.info()
July
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5683049 entries, 0 to 5683048
# Data columns (total 8 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Station Code             object
#  1   Station Name             object
#  2   Train Number             int64
#  3   Train Type               object
#  4   Train Company            object
#  5   Train Destination        object
#  6   Train Planned Departure  object
#  7   Train Delay              object
# dtypes: int64(1), object(7)
# memory usage: 346.9+ MB
#         Station Code            Station Name  Train Number Train Type  \
# 0               ASSP  Amsterdam Science Park          5882   Sprinter
# 1                SDM        Schiedam Centrum          4191   Sprinter
# 2                NWL      Schiedam Nieuwland          4191   Sprinter
# 3                HIL                Hillegom          6395   Sprinter
# 4                NWL      Schiedam Nieuwland          4191   Sprinter
# ...

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date
July['Train Planned Departure']=pd.to_datetime(July['Train Planned Departure'], format="%Y-%m-%dT%H:%M:%SZ")
July['Train Planned Departure1']=July['Train Planned Departure'].astype(str)
July[['DepartureDate','DepartureTime']]= July['Train Planned Departure1'].str.split(' ', expand = True)
July['DepartureDate']=pd.to_datetime(July['DepartureDate'])
July
#then i make the depature time a time delta (Actually want to make it a normal time format)
July['DepartureTime']=pd.to_timedelta(July['DepartureTime'].str.strip())
print(July.info())
July
#Then i also put the delay in time delta format
July['Train Delay']=pd.to_timedelta(July['Train Delay'].str.strip())
July
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5683049 entries, 0 to 5683048
# Data columns (total 11 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Station Code              object
#  1   Station Name              object
#  2   Train Number              int64
#  3   Train Type                object
#  4   Train Company             object
#  5   Train Destination         object
#  6   Train Planned Departure   datetime64[ns]
#  7   Train Delay               object
#  8   Train Planned Departure1  object
#  9   DepartureDate             datetime64[ns]
#  10  DepartureTime             timedelta64[ns]
# dtypes: datetime64[ns](2), int64(1), object(7), timedelta64[ns](1)
# memory usage: 476.9+ MB
# None
#         Station Code            Station Name  Train Number Train Type  \
# 0               ASSP  Amsterdam Science Park          5882   Sprinter
# 1                SDM        Schiedam Centrum          4191   Sprinter
# ...

# %%
August=pd.read_csv('August.csv')
August.drop('Unnamed: 0',axis=1,inplace=True)
August.info()
August
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5692769 entries, 0 to 5692768
# Data columns (total 8 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Station Code             object
#  1   Station Name             object
#  2   Train Number             int64
#  3   Train Type               object
#  4   Train Company            object
#  5   Train Destination        object
#  6   Train Planned Departure  object
#  7   Train Delay              object
# dtypes: int64(1), object(7)
# memory usage: 347.5+ MB
#         Station Code          Station Name  Train Number Train Type  \
# 0               NSCH      Bad Nieuweschans         37598  Stoptrein
# 1               HLMS   Haarlem Spaarnwoude         14882   Sprinter
# 2                HWD         Heerhugowaard          4082   Sprinter
# 3                VDW      Vlaardingen West          4197   Sprinter
# 4                SDM      Schiedam Centrum         15195   Sprinter
# ...

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date
August['Train Planned Departure']=pd.to_datetime(August['Train Planned Departure'], format="%Y-%m-%dT%H:%M:%SZ")
August['Train Planned Departure1']=August['Train Planned Departure'].astype(str)
August[['DepartureDate','DepartureTime']]= August['Train Planned Departure1'].str.split(' ', expand = True)
August['DepartureDate']=pd.to_datetime(August['DepartureDate'])
August
# Out:
#         Station Code          Station Name  Train Number Train Type  \
# 0               NSCH      Bad Nieuweschans         37598  Stoptrein
# 1               HLMS   Haarlem Spaarnwoude         14882   Sprinter
# 2                HWD         Heerhugowaard          4082   Sprinter
# 3                VDW      Vlaardingen West          4197   Sprinter
# 4                SDM      Schiedam Centrum         15195   Sprinter
# ...              ...                   ...           ...        ...
# 5692764          ASD    Amsterdam Centraal         12682  Intercity
# 5692765          ASS  Amsterdam Sloterdijk         12682  Intercity
# 5692766         ASDL    Amsterdam Lelylaan         12682  Intercity
# 5692767          SHL      Schiphol Airport         12682  Intercity
# 5692768         LEDN       Leiden Centraal         12682  Intercity
#
#         Train Company   Train Destination Train Planned Departure Train Delay  \
# ...

# %%
#then i make the depature time a time delta (Actually want to make it a normal time format)
August['DepartureTime']=pd.to_timedelta(August['DepartureTime'].str.strip())
print(August.info())
August
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5692769 entries, 0 to 5692768
# Data columns (total 11 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Station Code              object
#  1   Station Name              object
#  2   Train Number              int64
#  3   Train Type                object
#  4   Train Company             object
#  5   Train Destination         object
#  6   Train Planned Departure   datetime64[ns]
#  7   Train Delay               object
#  8   Train Planned Departure1  object
#  9   DepartureDate             datetime64[ns]
#  10  DepartureTime             timedelta64[ns]
# dtypes: datetime64[ns](2), int64(1), object(7), timedelta64[ns](1)
# memory usage: 477.8+ MB
# None
#         Station Code          Station Name  Train Number Train Type  \
# 0               NSCH      Bad Nieuweschans         37598  Stoptrein
# 1               HLMS   Haarlem Spaarnwoude         14882   Sprinter
# ...

# %%
#Then i also put the delay in time delta format
August['Train Delay']=pd.to_timedelta(August['Train Delay'].str.strip())
August
# Out:
#         Station Code          Station Name  Train Number Train Type  \
# 0               NSCH      Bad Nieuweschans         37598  Stoptrein
# 1               HLMS   Haarlem Spaarnwoude         14882   Sprinter
# 2                HWD         Heerhugowaard          4082   Sprinter
# 3                VDW      Vlaardingen West          4197   Sprinter
# 4                SDM      Schiedam Centrum         15195   Sprinter
# ...              ...                   ...           ...        ...
# 5692764          ASD    Amsterdam Centraal         12682  Intercity
# 5692765          ASS  Amsterdam Sloterdijk         12682  Intercity
# 5692766         ASDL    Amsterdam Lelylaan         12682  Intercity
# 5692767          SHL      Schiphol Airport         12682  Intercity
# 5692768         LEDN       Leiden Centraal         12682  Intercity
#
#         Train Company   Train Destination Train Planned Departure  \
# 0              Arriva           Groningen     2016-07-31 23:10:00
# ...

# %%
September=pd.read_csv('September.csv')
September.drop('Unnamed: 0',axis=1,inplace=True)
September.info()
September
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5697591 entries, 0 to 5697590
# Data columns (total 8 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Station Code             object
#  1   Station Name             object
#  2   Train Number             int64
#  3   Train Type               object
#  4   Train Company            object
#  5   Train Destination        object
#  6   Train Planned Departure  object
#  7   Train Delay              object
# dtypes: int64(1), object(7)
# memory usage: 347.8+ MB
#         Station Code         Station Name  Train Number Train Type  \
# 0               HLMS  Haarlem Spaarnwoude         14882   Sprinter
# 1                 BV            Beverwijk         14895   Sprinter
# 2               NSCH     Bad Nieuweschans         37598  Stoptrein
# 3                ZVT    Zandvoort aan Zee          5480   Sprinter
# 4               HWZB   Halfweg-Zwanenburg          5478   Sprinter
# ...

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date
September['Train Planned Departure']=pd.to_datetime(September['Train Planned Departure'], format="%Y-%m-%dT%H:%M:%SZ")
September['Train Planned Departure1']=September['Train Planned Departure'].astype(str)
September[['DepartureDate','DepartureTime']]= September['Train Planned Departure1'].str.split(' ', expand = True)
September['DepartureDate']=pd.to_datetime(September['DepartureDate'])
September
#then i make the depature time a time delta (Actually want to make it a normal time format)
September['DepartureTime']=pd.to_timedelta(September['DepartureTime'].str.strip())
print(September.info())
September
#Then i also put the delay in time delta format
September['Train Delay']=pd.to_timedelta(September['Train Delay'].str.strip())
September
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5697591 entries, 0 to 5697590
# Data columns (total 11 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Station Code              object
#  1   Station Name              object
#  2   Train Number              int64
#  3   Train Type                object
#  4   Train Company             object
#  5   Train Destination         object
#  6   Train Planned Departure   datetime64[ns]
#  7   Train Delay               object
#  8   Train Planned Departure1  object
#  9   DepartureDate             datetime64[ns]
#  10  DepartureTime             timedelta64[ns]
# dtypes: datetime64[ns](2), int64(1), object(7), timedelta64[ns](1)
# memory usage: 478.2+ MB
# None
#         Station Code         Station Name  Train Number Train Type  \
# 0               HLMS  Haarlem Spaarnwoude         14882   Sprinter
# 1                 BV            Beverwijk         14895   Sprinter
# ...

# %%
October=pd.read_csv('October.csv')
October.drop('Unnamed: 0',axis=1,inplace=True)
October.info()
October
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5805596 entries, 0 to 5805595
# Data columns (total 8 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Station Code             object
#  1   Station Name             object
#  2   Train Number             int64
#  3   Train Type               object
#  4   Train Company            object
#  5   Train Destination        object
#  6   Train Planned Departure  object
#  7   Train Delay              object
# dtypes: int64(1), object(7)
# memory usage: 354.3+ MB
#         Station Code          Station Name  Train Number Train Type  \
# 0                 BV             Beverwijk         14895   Sprinter
# 1                VDW      Vlaardingen West          4197   Sprinter
# 2               GERP  Groningen Europapark          9196   Sprinter
# 3               NSCH      Bad Nieuweschans         37598  Stoptrein
# 4               HLMS   Haarlem Spaarnwoude         14882   Sprinter
# ...

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date
October['Train Planned Departure']=pd.to_datetime(October['Train Planned Departure'], format="%Y-%m-%dT%H:%M:%SZ")
October['Train Planned Departure1']=October['Train Planned Departure'].astype(str)
October[['DepartureDate','DepartureTime']]= October['Train Planned Departure1'].str.split(' ', expand = True)
October['DepartureDate']=pd.to_datetime(October['DepartureDate'])
October
#then i make the depature time a time delta (Actually want to make it a normal time format)
October['DepartureTime']=pd.to_timedelta(October['DepartureTime'].str.strip())
print(October.info())
October
#Then i also put the delay in time delta format
October['Train Delay']=pd.to_timedelta(October['Train Delay'].str.strip())
October
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5805596 entries, 0 to 5805595
# Data columns (total 11 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Station Code              object
#  1   Station Name              object
#  2   Train Number              int64
#  3   Train Type                object
#  4   Train Company             object
#  5   Train Destination         object
#  6   Train Planned Departure   datetime64[ns]
#  7   Train Delay               object
#  8   Train Planned Departure1  object
#  9   DepartureDate             datetime64[ns]
#  10  DepartureTime             timedelta64[ns]
# dtypes: datetime64[ns](2), int64(1), object(7), timedelta64[ns](1)
# memory usage: 487.2+ MB
# None
#         Station Code          Station Name  Train Number Train Type  \
# 0                 BV             Beverwijk         14895   Sprinter
# 1                VDW      Vlaardingen West          4197   Sprinter
# ...

# %%
November=pd.read_csv('November.csv')
November.drop('Unnamed: 0',axis=1,inplace=True)
November.info()
November
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6252976 entries, 0 to 6252975
# Data columns (total 8 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Station Code             object
#  1   Station Name             object
#  2   Train Number             int64
#  3   Train Type               object
#  4   Train Company            object
#  5   Train Destination        object
#  6   Train Planned Departure  object
#  7   Train Delay              object
# dtypes: int64(1), object(7)
# memory usage: 381.7+ MB
#         Station Code           Station Name  Train Number Train Type  \
# 0                VDW       Vlaardingen West          4197   Sprinter
# 1                SDM       Schiedam Centrum         15195   Sprinter
# 2               NSCH       Bad Nieuweschans         37598  Stoptrein
# 3               HLMS    Haarlem Spaarnwoude         14882   Sprinter
# 4                GDM           Geldermalsen          6086   Sprinter
# ...

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date
November['Train Planned Departure']=pd.to_datetime(November['Train Planned Departure'], format="%Y-%m-%dT%H:%M:%SZ")
November['Train Planned Departure1']=November['Train Planned Departure'].astype(str)
November[['DepartureDate','DepartureTime']]= November['Train Planned Departure1'].str.split(' ', expand = True)
November['DepartureDate']=pd.to_datetime(November['DepartureDate'])
November
#then i make the depature time a time delta (Actually want to make it a normal time format)
November['DepartureTime']=pd.to_timedelta(November['DepartureTime'].str.strip())
print(November.info())
November
#Then i also put the delay in time delta format
November['Train Delay']=pd.to_timedelta(November['Train Delay'].str.strip())
November
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6252976 entries, 0 to 6252975
# Data columns (total 11 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Station Code              object
#  1   Station Name              object
#  2   Train Number              int64
#  3   Train Type                object
#  4   Train Company             object
#  5   Train Destination         object
#  6   Train Planned Departure   datetime64[ns]
#  7   Train Delay               object
#  8   Train Planned Departure1  object
#  9   DepartureDate             datetime64[ns]
#  10  DepartureTime             timedelta64[ns]
# dtypes: datetime64[ns](2), int64(1), object(7), timedelta64[ns](1)
# memory usage: 524.8+ MB
# None
#         Station Code           Station Name  Train Number Train Type  \
# 0                VDW       Vlaardingen West          4197   Sprinter
# 1                SDM       Schiedam Centrum         15195   Sprinter
# ...

# %%
December=pd.read_csv('December.csv')
December.drop('Unnamed: 0',axis=1,inplace=True)
December.info()
December
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1225410 entries, 0 to 1225409
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   Station Code             1223493 non-null  object
#  1   Station Name             1225410 non-null  object
#  2   Train Number             1225410 non-null  int64
#  3   Train Type               1225410 non-null  object
#  4   Train Company            1225410 non-null  object
#  5   Train Destination        1225410 non-null  object
#  6   Train Planned Departure  1225410 non-null  object
#  7   Train Delay              1225410 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 74.8+ MB
#         Station Code           Station Name  Train Number Train Type  \
# 0               HLMS    Haarlem Spaarnwoude         14882   Sprinter
# 1                 BV              Beverwijk         14895   Sprinter
# ...

# %%
#First I make a date from the date planned departure, then i make it a string in a new column fo i can split it into 2 columns 
#and make the date alone a date
December['Train Planned Departure']=pd.to_datetime(December['Train Planned Departure'], format="%Y-%m-%dT%H:%M:%SZ")
December['Train Planned Departure1']=December['Train Planned Departure'].astype(str)
December[['DepartureDate','DepartureTime']]= December['Train Planned Departure1'].str.split(' ', expand = True)
December['DepartureDate']=pd.to_datetime(December['DepartureDate'])
December
#then i make the depature time a time delta (Actually want to make it a normal time format)
December['DepartureTime']=pd.to_timedelta(December['DepartureTime'].str.strip())
print(December.info())
December
#Then i also put the delay in time delta format
December['Train Delay']=pd.to_timedelta(December['Train Delay'].str.strip())
December
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1225410 entries, 0 to 1225409
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   Station Code              1223493 non-null  object
#  1   Station Name              1225410 non-null  object
#  2   Train Number              1225410 non-null  int64
#  3   Train Type                1225410 non-null  object
#  4   Train Company             1225410 non-null  object
#  5   Train Destination         1225410 non-null  object
#  6   Train Planned Departure   1225410 non-null  datetime64[ns]
#  7   Train Delay               1225410 non-null  object
#  8   Train Planned Departure1  1225410 non-null  object
#  9   DepartureDate             1225410 non-null  datetime64[ns]
#  10  DepartureTime             1225410 non-null  timedelta64[ns]
# dtypes: datetime64[ns](2), int64(1), object(7), timedelta64[ns](1)
# memory usage: 102.8+ MB
# None
# ...

# %%
TrainData=pd.concat([January, February, March, April, May, June, July, August, September, October, November, December])
TrainData.index = range(63471443)
TrainData
# Out:
#          Station Code            Station Name  Train Number Train Type  \
# 0                HLMS     Haarlem Spaarnwoude         14882   Sprinter
# 1                NSCH        Bad Nieuweschans         37598  Stoptrein
# 2                 DVD            Duivendrecht          7495   Sprinter
# 3                DDRS  Dordrecht Stadspolders         36795  Stoptrein
# 4                EMNZ              Emmen Zuid          8083  Stoptrein
# ...               ...                     ...           ...        ...
# 63471438          ASD      Amsterdam Centraal          1406  Intercity
# 63471439           DT                   Delft          1410  Intercity
# 63471440           GV             Den Haag HS          1414  Intercity
# 63471441         LEDN         Leiden Centraal          1409  Intercity
# 63471442           DT                   Delft          1410  Intercity
#
#          Train Company       Train Destination Train Planned Departure  \
# ...

# %%
TrainData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63471443 entries, 0 to 63471442
# Data columns (total 11 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Station Code              object
#  1   Station Name              object
#  2   Train Number              int64
#  3   Train Type                object
#  4   Train Company             object
#  5   Train Destination         object
#  6   Train Planned Departure   datetime64[ns]
#  7   Train Delay               timedelta64[ns]
#  8   Train Planned Departure1  object
#  9   DepartureDate             datetime64[ns]
#  10  DepartureTime             timedelta64[ns]
# dtypes: datetime64[ns](2), int64(1), object(6), timedelta64[ns](2)
# memory usage: 5.2+ GB
